# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import fsolve
from scipy.optimize import brentq
import time
import matplotlib.pyplot as plt

g = 0.8
Nk = 256

U = 2
Tc_final = np.load(f'Tc_U{U}_g{g}_N{Nk}_variational.npy')
x_final = np.load(f'x_U{U}_g{g}_N{Nk}_variational.npy')
delta_final = np.load(f'delta_U{U}_g{g}_N{Nk}_variational.npy')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 12
#       9 Nk = 256
#      11 U = 2
# ---> 12 Tc_final = np.load(f'Tc_U{U}_g{g}_N{Nk}_variational.npy')
#      13 x_final = np.load(f'x_U{U}_g{g}_N{Nk}_variational.npy')
#      14 delta_final = np.load(f'delta_U{U}_g{g}_N{Nk}_variational.npy')
#
# File d:\ANACONDA3\Lib\site-packages\numpy\lib\npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Tc_U2_g0.8_N256_variational.npy'

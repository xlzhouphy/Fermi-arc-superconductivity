# %%
#Fermi arc model zero-temperature gap (variational method) equation 13
import matplotlib.pyplot as plt
plt.style.use("publication")
import numpy as np
from scipy.optimize import fsolve
from scipy.optimize import brentq
from scipy.optimize import root
import time

kB = 1.0
t = 1.0
t1 = -0.2
t2 = 0.1
g = 0.8  # 0.8, 2.0

Q = [np.pi, np.pi]

U = 0.0  # 0.0, 2.0

Nk = 64 #64 128 256
kx_list = np.linspace(-np.pi, np.pi, Nk, endpoint=False)
ky_list = np.linspace(-np.pi, np.pi, Nk, endpoint=False)
KX, KY = np.meshgrid(kx_list, ky_list)
N = Nk * Nk

def band(kx, ky):
    return -2.0*t*(np.cos(kx) + np.cos(ky)) - 4.0*t1*np.cos(kx)*np.cos(ky) - 2*t2*(np.cos(2*kx) + np.cos(2*ky))

def band_Q(kx, ky):
    return -2.0*t*(np.cos(kx+Q[0]) + np.cos(ky+Q[1])) - 4.0*t1*np.cos(kx+Q[0])*np.cos(ky+Q[1]) - 2*t2*(np.cos(2*(kx+Q[0])) + np.cos(2*(ky+Q[1])))

def occupation_Q_per_spin(epsilon, epsilon_Q, mu, U, T):
    epsilon_minus_mu = epsilon - mu
    epsilon_Q_minus_mu = epsilon_Q - mu
    if T < 1e-8:
        T = 1e-8
    beta = 1.0/T
    E_1 = -beta*epsilon_Q_minus_mu
    E_2 = -beta*(epsilon_minus_mu + epsilon_Q_minus_mu + U)
    E_3 = -beta*epsilon_minus_mu
    E_0 = np.full_like(E_1, 0)
    E_max = np.maximum.reduce([E_0, E_1, E_2, E_3])
    numerator = np.exp(E_1 - E_max) + np.exp(E_2 - E_max)
    denominator = np.exp(E_0 - E_max) + np.exp(E_3 - E_max) + np.exp(E_1 - E_max) + np.exp(E_2 - E_max)
    return numerator/denominator

def chi0_hk(T, mu, U):
    if T < 1e-8:
        T = 1e-8
    beta = 1.0/T
    epsilon = band(KX, KY)
    epsilon_Q = band_Q(KX, KY)
    n_k = occupation_Q_per_spin(epsilon, epsilon_Q, mu, U, T)
    epsilon_minus_mu = epsilon - mu
    epsilon_Q_minus_mu = epsilon_Q - mu
    gamma = np.cos(KX) - np.cos(KY)
    #gamma = 1
    
    term_1_denominator = 2.0*epsilon_minus_mu
    term_1_numerator = gamma*gamma*(1.0 - n_k)*np.tanh(beta*epsilon_minus_mu/2.0)
    term_1 = np.where(np.abs(epsilon_minus_mu) < 1e-6, 
                      (1.0 - n_k)*beta/4.0,
                     term_1_numerator/term_1_denominator)
    
    epsilon_plus_U = epsilon_minus_mu + U
    term_2_denominator = 2.0*epsilon_plus_U
    term_2_numerator = gamma*gamma*n_k*np.tanh(beta*epsilon_plus_U/2.0)
    term_2 = np.where(np.abs(epsilon_plus_U) < 1e-6, 
                      n_k*beta/4.0,
                     term_2_numerator/term_2_denominator)

    term_3_denominator = 2.0*epsilon_minus_mu + U
    term_3_numerator = gamma*gamma*n_k*(1-n_k)*U*(np.tanh(beta*epsilon_plus_U/2.0)/2/epsilon_plus_U - np.tanh(beta*epsilon_minus_mu/2.0)/2/epsilon_minus_mu)
    term_3 = term_3_numerator/term_3_denominator
    #term_3 = 0
    
    chi0 = np.sum(term_1 + term_2 + term_3)/N
    return chi0

def tc_equation(T, mu, U, g):
    return g*chi0_hk(T, mu, U) - 1.0

def find_Tc(mu, U, g):
    T_max = 1.0
    T_min = 1e-7
    if tc_equation(T_max, mu, U, g) > 0:
        T_high = T_max
        while tc_equation(T_high, mu, U, g) > 0 and T_high < 10.0:
            T_high *= 2
        T_max = T_high
        print('T_high=', T_max)
    if tc_equation(T_min, mu, U, g) < 0:
        print('mu =', mu, 'low Tc')
        return 0.0
    try:
        Tc = brentq(tc_equation, T_min, T_max, args=(mu, U, g))
        return Tc
    except ValueError:
        return 0.0
    return Tc

def average_occupation(mu, T, U, KX, KY, N):
    epsilon = band(KX, KY)
    epsilon_Q = band_Q(KX, KY)
    n_k = occupation_Q_per_spin(epsilon, epsilon_Q, mu, U, T)
    return 2.0*np.sum(n_k) / N

def gamma_func(kx, ky):
    #gamma = 1.0
    gamma = np.cos(kx) - np.cos(ky)
    return gamma

kmap = np.empty(Nk, dtype=np.int32)

for i in range(Nk):
    kmap[i] = (i+Nk//2)%Nk

def bcs_2d_system(theta_flat):
    theta = theta_flat.reshape(Nk, Nk)
    
    sin_2t = np.sin(2 * theta)
    cos_2t = np.cos(2 * theta)

    sin_q = np.sin(theta[np.ix_(kmap, kmap)])
    
    gap_sum = 0.5*g/N * np.sum(g_2d * sin_2t)
    
    residual = 2 * xi_2d * sin_2t + 2*U*sin_2t*sin_q*sin_q- 2 * g_2d * cos_2t * gap_sum
    return residual.flatten()

mu_list = np.linspace(0.70, -2.55, 150)  #U=2.0
#mu_list = np.linspace(0.5, -2.75, 150)  #U=1.7
#mu_list = np.linspace(0.1, -3.15, 150)  #U=1.4
#mu_list = np.linspace(-0.15, -3.4, 150)  #U=1.1

Tc_results = []
Doping_x_results = []
delta_results = []

start_time = time.time()
for mu in mu_list:
    Tc = find_Tc(mu, U, g)
    T_threshold = 1e-6
    if Tc > T_threshold:
        avg_n = average_occupation(mu, Tc, U, KX, KY, N)
        doping_x = 1.0 - avg_n
    else:
        avg_n = average_occupation(mu, T_threshold, U, KX, KY, N)
        doping_x = 1.0 - avg_n
    print('dopping_x =', doping_x, 'Tc =', Tc)
    Tc_results.append(Tc)
    Doping_x_results.append(doping_x)
    
    xi_2d = band(KX, KY) - mu
    g_2d = gamma_func(KX, KY)
    delta_guess = 0.2
    initial_theta = 0.5 * np.arctan2(delta_guess * g_2d, xi_2d)
    initial_theta_flat = initial_theta.flatten()
    delta = 0
    sol = root(
        bcs_2d_system, 
        initial_theta_flat, 
        method='df-sane',
        tol=1e-6,
    )
    if sol.success:
        theta_res = sol.x.reshape(Nk, Nk)
        delta = g/2/N * np.sum(g_2d * np.sin(2 * theta_res))
        print(f" Delta: {delta:.6f}")
    else:
        print("error", sol.message)
    delta_results.append(delta)

x_plot = np.array(Doping_x_results)
Tc_plot = np.array(Tc_results)
delta_plot = np.array(delta_results)

mask_lower = x_plot >= 0.1
mask_upper = x_plot < 0.8
mask_combined = mask_lower & mask_upper

Tc_final = Tc_plot[mask_combined]
x_final = x_plot[mask_combined]
delta_final = delta_plot[mask_combined]

sort_indices = np.argsort(x_final)
x_final = x_final[sort_indices]
Tc_final = Tc_final[sort_indices]

end_time = time.time()
print(end_time-start_time)

#np.save(f'Tc_U{U:g}_g{g:g}_N{Nk:g}_variational', Tc_final)
#np.save(f'x_U{U:g}_g{g:g}_N{Nk:g}_variational', x_final)
#np.save(f'delta_U{U:g}_g{g:g}_N{Nk:g}_variational', delta_final)


plt.figure()
plt.plot(x_final, Tc_final, 'o-', color='tab:orange', linewidth=2, markersize=4, label=f'$U={U}, g={g}$, Tc')
plt.plot(x_final, delta_final, 'o-', linewidth=2, markersize=4, label=f'$U={U}, g={g}$, gap')
plt.xlabel('p')
plt.ylabel('Energy')
plt.grid(True, linestyle='--', alpha=0.7)
plt.xlim(0, 0.8)
plt.ylim(bottom=0)
plt.legend()

plt.show()
# Out:
# mu = 0.7 low Tc
# dopping_x = -0.31396484375 Tc = 0.0
#  Delta: 0.000000
# mu = 0.6781879194630872 low Tc
# dopping_x = -0.31396484375 Tc = 0.0
#  Delta: 0.000000
# mu = 0.6563758389261745 low Tc
# dopping_x = -0.31396484375 Tc = 0.0
#  Delta: 0.000001
# mu = 0.6345637583892617 low Tc
# dopping_x = -0.30224609375 Tc = 0.0
#  Delta: 0.000001
# mu = 0.612751677852349 low Tc
# dopping_x = -0.30224609375 Tc = 0.0
#  Delta: 0.000000
# dopping_x = -0.29775064249222094 Tc = 0.003966605097073433
# error too many function evaluations required
# dopping_x = -0.28600273888372874 Tc = 0.004535728740871641
#  Delta: 0.006091
# mu = 0.5473154362416107 low Tc
# dopping_x = -0.27685546875 Tc = 0.0
#  Delta: 0.000002
# dopping_x = -0.27133969067028296 Tc = 0.0027487860707579434
#  Delta: 0.004103
# mu = 0.5036912751677852 low Tc
# dopping_x = -0.26904296875 Tc = 0.0
#  Delta: 0.000001
# mu = 0.4818791946308725 low Tc
# dopping_x = -0.25732421875 Tc = 0.0
#  Delta: 0.000005
# mu = 0.46006711409395973 low Tc
# dopping_x = -0.25732421875 Tc = 0.0
#  Delta: 0.000000
# dopping_x = -0.25372163628087163 Tc = 0.001175039385995628
# error too many function evaluations required
# mu = 0.4164429530201342 low Tc
# dopping_x = -0.25341796875 Tc = 0.0
#  Delta: 0.000000
# dopping_x = -0.24632480861900952 Tc = 0.0013514871228826346
#  Delta: 0.002741
# mu = 0.3728187919463087 low Tc
# dopping_x = -0.23583984375 Tc = 0.0
#  Delta: 0.000001
# mu = 0.35100671140939593 low Tc
# dopping_x = -0.23583984375 Tc = 0.0
#  Delta: 0.000000
# dopping_x = -0.23165042167775374 Tc = 0.0041468364458391235
#  Delta: 0.004212
# dopping_x = -0.2220247806607496 Tc = 0.007973067325303798
#  Delta: 0.010201
# dopping_x = -0.21401236711975669 Tc = 0.006563090950544452
#  Delta: 0.009169
# dopping_x = -0.2068340373426545 Tc = 0.00474649283993829
#  Delta: 0.007210
# dopping_x = -0.2021734712525991 Tc = 0.002508392903927096
#  Delta: 0.003374
# dopping_x = -0.19498949336554494 Tc = 0.0019261517081902977
#  Delta: 0.001817
# mu = 0.19832214765100664 low Tc
# dopping_x = -0.19091796875 Tc = 0.0
#  Delta: 0.000000
# dopping_x = -0.18694296308042468 Tc = 0.0016765873640469345
# error too many function evaluations required
# mu = 0.15469798657718115 low Tc
# dopping_x = -0.17919921875 Tc = 0.0
#  Delta: 0.000001
# dopping_x = -0.174656172327599 Tc = 0.0025191635749847122
#  Delta: 0.003364
# mu = 0.11107382550335565 low Tc
# dopping_x = -0.16748046875 Tc = 0.0
#  Delta: 0.000000
# mu = 0.0892617449664429 low Tc
# dopping_x = -0.16748046875 Tc = 0.0
#  Delta: 0.000000
# dopping_x = -0.16255260706769326 Tc = 0.010302292690154383
#  Delta: 0.012883
# dopping_x = -0.15318489949310798 Tc = 0.012437474928923588
#  Delta: 0.016335
# dopping_x = -0.1440357288103482 Tc = 0.011365542690316945
#  Delta: 0.013811
# dopping_x = -0.13624138436346067 Tc = 0.009355398246101753
#  Delta: 0.011518
# dopping_x = -0.1283142775091095 Tc = 0.007550036845377632
#  Delta: 0.009575
# dopping_x = -0.12449897054730807 Tc = 0.0005655086682955831
# error too many function evaluations required
# dopping_x = -0.11803823067691499 Tc = 0.005957796605583089
#  Delta: 0.008732
# dopping_x = -0.11246592932670674 Tc = 0.004042334091935336
#  Delta: 0.004983
# dopping_x = -0.10680514195470714 Tc = 0.0057694716510691135
#  Delta: 0.009373
# mu = -0.12885906040268458 low Tc
# dopping_x = -0.10107421875 Tc = 0.0
# error too many function evaluations required
# dopping_x = -0.10068549356899759 Tc = 0.008338895094070256
#  Delta: 0.006314
# dopping_x = -0.09271606419909029 Tc = 0.016574768168665866
#  Delta: 0.020304
# dopping_x = -0.08278777025298956 Tc = 0.01901131943096872
#  Delta: 0.024394
# dopping_x = -0.0731882991291748 Tc = 0.019311151196401914
#  Delta: 0.023741
# dopping_x = -0.06485844117641193 Tc = 0.018392184933887425
#  Delta: 0.021884
# dopping_x = -0.057866111078650695 Tc = 0.01688093858505389
#  Delta: 0.020953
# dopping_x = -0.05201428101858152 Tc = 0.015545499510210246
#  Delta: 0.018643
# dopping_x = -0.046599942322829824 Tc = 0.015435505160888681
#  Delta: 0.020153
# dopping_x = -0.04101627627518889 Tc = 0.01617260017142179
#  Delta: 0.021685
# dopping_x = -0.035701066335096066 Tc = 0.018388063890629254
#  Delta: 0.021648
# dopping_x = -0.029528465374539348 Tc = 0.02276781736154652
#  Delta: 0.024921
# dopping_x = -0.021528759405595288 Tc = 0.02674282141775836
#  Delta: 0.031772
# dopping_x = -0.012874316470087743 Tc = 0.029354569819589123
#  Delta: 0.035884
# dopping_x = -0.004358668619332651 Tc = 0.030902187738054587
#  Delta: 0.037257
# dopping_x = 0.003649126201114017 Tc = 0.03179059578168001
#  Delta: 0.037341
# dopping_x = 0.011057239397705976 Tc = 0.032470444006847454
#  Delta: 0.037963
# dopping_x = 0.018021633000568027 Tc = 0.03344330376558579
#  Delta: 0.038533
# dopping_x = 0.024910227255106943 Tc = 0.03510999178757748
#  Delta: 0.040459
# dopping_x = 0.03210970252460299 Tc = 0.0375226075455133
#  Delta: 0.043024
# dopping_x = 0.03979998254050254 Tc = 0.040356405698226835
#  Delta: 0.045750
# dopping_x = 0.0479107387761839 Tc = 0.0432095623849838
#  Delta: 0.049297
# dopping_x = 0.056250274716129756 Tc = 0.04587639109651091
#  Delta: 0.052659
# dopping_x = 0.0646473911282619 Tc = 0.04835839791394386
#  Delta: 0.055542
# dopping_x = 0.07302026276514462 Tc = 0.050768224334175036
#  Delta: 0.057556
# dopping_x = 0.08138732539786209 Tc = 0.053239624369062065
#  Delta: 0.059618
# dopping_x = 0.08983397196553833 Tc = 0.05585861921556855
#  Delta: 0.061983
# dopping_x = 0.09845181004302017 Tc = 0.0586340639996653
#  Delta: 0.064638
# dopping_x = 0.10729221296295699 Tc = 0.06151973532449701
#  Delta: 0.067639
# dopping_x = 0.1163627810486445 Tc = 0.06445860763837079
#  Delta: 0.070910
# dopping_x = 0.12565193312967704 Tc = 0.06741019059689081
#  Delta: 0.074035
# dopping_x = 0.13515284466301425 Tc = 0.07035217766162849
#  Delta: 0.076951
# dopping_x = 0.144873272719793 Tc = 0.07326950754432451
#  Delta: 0.079745
# dopping_x = 0.15483261298572448 Tc = 0.07614417152796811
#  Delta: 0.082442
# dopping_x = 0.1650533459907515 Tc = 0.07895134714365246
#  Delta: 0.085096
# dopping_x = 0.17555357438657604 Tc = 0.08166089367436313
#  Delta: 0.087772
# dopping_x = 0.18634364309405815 Tc = 0.0842407470824127
#  Delta: 0.090455
# dopping_x = 0.19742623615204535 Tc = 0.08665966990395634
#  Delta: 0.093194
# dopping_x = 0.20879798736692068 Tc = 0.08888867690416001
#  Delta: 0.095896
# dopping_x = 0.22045112769556807 Tc = 0.09090150688191957
#  Delta: 0.098184
# dopping_x = 0.23237462385946084 Tc = 0.09267463047052538
#  Delta: 0.100205
# dopping_x = 0.24455484044480147 Tc = 0.09418705584040261
#  Delta: 0.101976
# dopping_x = 0.2569759216402767 Tc = 0.09542001223585415
#  Delta: 0.103499
# dopping_x = 0.26962004542226614 Tc = 0.09635652968029716
#  Delta: 0.104769
# dopping_x = 0.28246761846514945 Tc = 0.0969809341258605
#  Delta: 0.105787
# dopping_x = 0.2954974207304819 Tc = 0.09727828683129429
#  Delta: 0.106564
# dopping_x = 0.30868668087986517 Tc = 0.0972337959454614
#  Delta: 0.107096
# dopping_x = 0.3220110547088979 Tc = 0.09683221919834559
#  Delta: 0.107074
# dopping_x = 0.3354444764907407 Tc = 0.09605726631053293
#  Delta: 0.106487
# dopping_x = 0.34895885003485505 Tc = 0.0948910037083386
#  Delta: 0.105389
# dopping_x = 0.3625235386008401 Tc = 0.09331326633690926
#  Delta: 0.103784
# dopping_x = 0.37610459844754784 Tc = 0.09130109693675613
#  Delta: 0.101674
# dopping_x = 0.38966367829646 Tc = 0.08882827255549902
#  Delta: 0.099073
# dopping_x = 0.4031564760609371 Tc = 0.08586506338045423
#  Delta: 0.096029
# dopping_x = 0.4165306094808725 Tc = 0.0823785452561042
#  Delta: 0.092664
# dopping_x = 0.4297227416443776 Tc = 0.07833413918086486
#  Delta: 0.088610
# dopping_x = 0.4426548892576295 Tc = 0.07369971438559426
#  Delta: 0.083783
# dopping_x = 0.4552303038786608 Tc = 0.06845468473461618
#  Delta: 0.078309
# dopping_x = 0.4673309603326641 Tc = 0.06260772778773338
#  Delta: 0.072261
# dopping_x = 0.4788234489569444 Tc = 0.05622590445115695
#  Delta: 0.065743
# dopping_x = 0.489590284110039 Tc = 0.049469097022545774
#  Delta: 0.058926
# dopping_x = 0.4996119589171427 Tc = 0.04260161034079957
#  Delta: 0.052057
# dopping_x = 0.509083844478841 Tc = 0.0359378104459597
#  Delta: 0.045718
# dopping_x = 0.5184041967842123 Tc = 0.02977527820968173
#  Delta: 0.040103
# dopping_x = 0.5278892575730767 Tc = 0.024520572983220478
#  Delta: 0.034959
# dopping_x = 0.5374667250477545 Tc = 0.02025436460909518
#  Delta: 0.030167
# dopping_x = 0.5464739738423912 Tc = 0.015928847165099565
#  Delta: 0.022877
# dopping_x = 0.5529877634006661 Tc = 0.010661831909233423
#  Delta: 0.013936
# dopping_x = 0.5561760670224956 Tc = 0.005007749751250854
#  Delta: 0.005077
# dopping_x = 0.5593809740448392 Tc = 0.005060800552029453
#  Delta: 0.006897
# dopping_x = 0.5684156150025251 Tc = 0.00745878885213238
# error too many function evaluations required
# dopping_x = 0.5882679678651419 Tc = 0.007305474201175712
#  Delta: 0.013635
# mu = -1.6993288590604025 low Tc
# dopping_x = 0.59716796875 Tc = 0.0
#  Delta: 0.000002
# dopping_x = 0.5975862874106452 Tc = 0.0015665399068874603
#  Delta: 0.002221
# mu = -1.7429530201342283 low Tc
# dopping_x = 0.60107421875 Tc = 0.0
# error too many function evaluations required
# dopping_x = 0.6048869311964156 Tc = 0.003181601524758302
#  Delta: 0.005498
# dopping_x = 0.6113996530944575 Tc = 0.0015542501052903945
# error too many function evaluations required
# mu = -1.8083892617449664 low Tc
# dopping_x = 0.61865234375 Tc = 0.0
# error too many function evaluations required
# dopping_x = 0.6375624266940288 Tc = 0.0013706739798645922
# error too many function evaluations required
# mu = -1.852013422818792 low Tc
# dopping_x = 0.64013671875 Tc = 0.0
#  Delta: 0.000000
# dopping_x = 0.643029817204046 Tc = 0.0014867704199412143
#  Delta: 0.002555
# mu = -1.8956375838926174 low Tc
# dopping_x = 0.64990234375 Tc = 0.0
#  Delta: 0.000001
# dopping_x = 0.6531155855592298 Tc = 0.0005455318144987375
# error too many function evaluations required
# mu = -1.939261744966443 low Tc
# dopping_x = 0.65380859375 Tc = 0.0
# error too many function evaluations required
# dopping_x = 0.6649453129805603 Tc = 0.00023690139854291381
# error too many function evaluations required
# mu = -1.9828859060402684 low Tc
# dopping_x = 0.67724609375 Tc = 0.0
# error too many function evaluations required
# dopping_x = 0.6846295919103202 Tc = 0.0007135590363219357
# error too many function evaluations required
# mu = -2.026510067114094 low Tc
# dopping_x = 0.68701171875 Tc = 0.0
#  Delta: 0.000000
# mu = -2.0483221476510067 low Tc
# dopping_x = 0.68701171875 Tc = 0.0
# error too many function evaluations required
# dopping_x = 0.6942103562497849 Tc = 0.0004867542175394208
# error too many function evaluations required
# mu = -2.0919463087248324 low Tc
# dopping_x = 0.69873046875 Tc = 0.0
#  Delta: -0.000000
# mu = -2.1137583892617453 low Tc
# dopping_x = 0.70654296875 Tc = 0.0
# error too many function evaluations required
# dopping_x = 0.7166206051619016 Tc = 0.00033244243393707704
# error too many function evaluations required
# mu = -2.15738255033557 low Tc
# dopping_x = 0.72216796875 Tc = 0.0
#  Delta: -0.000000
# mu = -2.179194630872483 low Tc
# dopping_x = 0.72216796875 Tc = 0.0
#  Delta: 0.000000
# mu = -2.201006711409396 low Tc
# dopping_x = 0.72998046875 Tc = 0.0
# error too many function evaluations required
# mu = -2.2228187919463087 low Tc
# dopping_x = 0.72998046875 Tc = 0.0
#  Delta: 0.000000
# mu = -2.2446308724832216 low Tc
# dopping_x = 0.73779296875 Tc = 0.0
# error too many function evaluations required
# mu = -2.2664429530201344 low Tc
# dopping_x = 0.74365234375 Tc = 0.0
# error too many function evaluations required
# mu = -2.2882550335570473 low Tc
# dopping_x = 0.75537109375 Tc = 0.0
#  Delta: 0.000000
# mu = -2.31006711409396 low Tc
# dopping_x = 0.75537109375 Tc = 0.0
#  Delta: 0.000000
# mu = -2.331879194630872 low Tc
# dopping_x = 0.75927734375 Tc = 0.0
# error too many function evaluations required
# mu = -2.353691275167785 low Tc
# dopping_x = 0.76318359375 Tc = 0.0
#  Delta: 0.000000
# mu = -2.375503355704698 low Tc
# dopping_x = 0.77099609375 Tc = 0.0
# error too many function evaluations required
# mu = -2.3973154362416107 low Tc
# dopping_x = 0.77294921875 Tc = 0.0
#  Delta: 0.000000
# mu = -2.4191275167785236 low Tc
# dopping_x = 0.78076171875 Tc = 0.0
#  Delta: 0.000000
# mu = -2.4409395973154364 low Tc
# dopping_x = 0.78662109375 Tc = 0.0
#  Delta: 0.000000
# mu = -2.4627516778523493 low Tc
# dopping_x = 0.78662109375 Tc = 0.0
#  Delta: 0.000000
# mu = -2.484563758389262 low Tc
# dopping_x = 0.79443359375 Tc = 0.0
#  Delta: 0.000000
# mu = -2.506375838926174 low Tc
# dopping_x = 0.79833984375 Tc = 0.0
# error too many function evaluations required
# mu = -2.528187919463087 low Tc
# dopping_x = 0.80419921875 Tc = 0.0
#  Delta: 0.000000
# mu = -2.55 low Tc
# dopping_x = 0.80810546875 Tc = 0.0
# error too many function evaluations required
# 61.42099452018738

# %%
#Fermi arc model Tc equation 25 (non-interacting interacting splited)
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import fsolve
from scipy.optimize import brentq
from scipy.optimize import root
import time

kB = 1.0
t = 1.0
t1 = -0.2
t2 = 0.1
g = 2.0

Q = [np.pi, np.pi]

U = 2.0

Nk = 256*2
kx_list = np.linspace(-np.pi, np.pi, Nk, endpoint=False)
ky_list = np.linspace(-np.pi, np.pi, Nk, endpoint=False)
KX, KY = np.meshgrid(kx_list, ky_list)
N = Nk * Nk

def band(kx, ky):
    return -2.0*t*(np.cos(kx) + np.cos(ky)) - 4.0*t1*np.cos(kx)*np.cos(ky) - 2*t2*(np.cos(2*kx) + np.cos(2*ky))

def band_Q(kx, ky):
    return -2.0*t*(np.cos(kx+Q[0]) + np.cos(ky+Q[1])) - 4.0*t1*np.cos(kx+Q[0])*np.cos(ky+Q[1]) - 2*t2*(np.cos(2*(kx+Q[0])) + np.cos(2*(ky+Q[1])))

def occupation_Q_per_spin(epsilon, epsilon_Q, mu, U, T):
    epsilon_minus_mu = epsilon - mu
    epsilon_Q_minus_mu = epsilon_Q - mu
    if T < 1e-8:
        T = 1e-8
    beta = 1.0/T
    E_1 = -beta*epsilon_Q_minus_mu
    E_2 = -beta*(epsilon_minus_mu + epsilon_Q_minus_mu + U)
    E_3 = -beta*epsilon_minus_mu
    E_0 = np.full_like(E_1, 0)
    E_max = np.maximum.reduce([E_0, E_1, E_2, E_3])
    numerator = np.exp(E_1 - E_max) + np.exp(E_2 - E_max)
    denominator = np.exp(E_0 - E_max) + np.exp(E_3 - E_max) + np.exp(E_1 - E_max) + np.exp(E_2 - E_max)
    return numerator/denominator

def chi0_hk(T, mu, U):
    if T < 1e-8:
        T = 1e-8
    beta = 1.0/T
    epsilon = band(KX, KY)
    epsilon_Q = band_Q(KX, KY)
    n_k = occupation_Q_per_spin(epsilon, epsilon_Q, mu, U, T)
    epsilon_minus_mu = epsilon - mu
    epsilon_Q_minus_mu = epsilon_Q - mu
    gamma = np.cos(KX) - np.cos(KY)
    #gamma = 1
    
    term_1_denominator = 2.0*epsilon_minus_mu
    term_1_numerator = gamma*gamma*(1.0 - n_k)*np.tanh(beta*epsilon_minus_mu/2.0)
    term_1 = np.where(np.abs(epsilon_minus_mu) < 1e-6, 
                      (1.0 - n_k)*beta/4.0,
                     term_1_numerator/term_1_denominator)
    
    epsilon_plus_U = epsilon_minus_mu + U
    term_2_denominator = 2.0*epsilon_plus_U
    term_2_numerator = gamma*gamma*n_k*np.tanh(beta*epsilon_plus_U/2.0)
    term_2 = np.where(np.abs(epsilon_plus_U) < 1e-6, 
                      n_k*beta/4.0,
                     term_2_numerator/term_2_denominator)

    term_3_denominator = 2.0*epsilon_minus_mu + U
    term_3_numerator = gamma*gamma*n_k*(1-n_k)*U*(np.tanh(beta*epsilon_plus_U/2.0)/2/epsilon_plus_U - np.tanh(beta*epsilon_minus_mu/2.0)/2/epsilon_minus_mu)
    term_3 = term_3_numerator/term_3_denominator
    #term_3 = 0
    
    chi0 = np.sum(term_1 + term_2 + term_3)/N
    return chi0

def tc_equation(T, mu, U, g):
    return g*chi0_hk(T, mu, U) - 1.0

def find_Tc(mu, U, g):
    T_max = 1.0
    T_min = 1e-7
    if tc_equation(T_max, mu, U, g) > 0:
        T_high = T_max
        while tc_equation(T_high, mu, U, g) > 0 and T_high < 10.0:
            T_high *= 2
        T_max = T_high
        print('T_high=', T_max)
    if tc_equation(T_min, mu, U, g) < 0:
        print('mu =', mu, 'low Tc')
        return 0.0
    try:
        Tc = brentq(tc_equation, T_min, T_max, args=(mu, U, g))
        return Tc
    except ValueError:
        return 0.0
    return Tc

def average_occupation(mu, T, U, KX, KY, N):
    epsilon = band(KX, KY)
    epsilon_Q = band_Q(KX, KY)
    n_k = occupation_Q_per_spin(epsilon, epsilon_Q, mu, U, T)
    return 2.0*np.sum(n_k) / N

def gamma_func(kx, ky):
    #gamma = 1.0
    gamma = np.cos(kx) - np.cos(ky)
    return gamma

kmap = np.empty(Nk, dtype=np.int32)

for i in range(Nk):
    kmap[i] = (i+Nk//2)%Nk

def bcs_2d_system(theta_flat):
    theta = theta_flat.reshape(Nk, Nk)
    
    sin_2t = np.sin(2 * theta)
    cos_2t = np.cos(2 * theta)

    sin_q = np.sin(theta[np.ix_(kmap, kmap)])
    
    gap_sum = 0.5*g/N * np.sum(g_2d * sin_2t)
    
    residual = 2 * xi_2d * sin_2t + 2*U*sin_2t*sin_q*sin_q- 2 * g_2d * cos_2t * gap_sum
    return residual.flatten()

mu_list = np.linspace(0.70, -2.55, 150)  #U=2.0
#mu_list = np.linspace(0.5, -2.75, 150)  #U=1.7
#mu_list = np.linspace(0.1, -3.15, 150)  #U=1.4
#mu_list = np.linspace(-0.15, -3.4, 150)  #U=1.1

Tc_results = []
Doping_x_results = []
delta_results = []

start_time = time.time()
for mu in mu_list:
    Tc = find_Tc(mu, U, g)
    T_threshold = 1e-6
    if Tc > T_threshold:
        avg_n = average_occupation(mu, Tc, U, KX, KY, N)
        doping_x = 1.0 - avg_n
    else:
        avg_n = average_occupation(mu, T_threshold, U, KX, KY, N)
        doping_x = 1.0 - avg_n
    print('dopping_x =', doping_x, 'Tc =', Tc)
    Tc_results.append(Tc)
    Doping_x_results.append(doping_x)
    
    xi_2d = band(KX, KY) - mu
    g_2d = gamma_func(KX, KY)
    delta_guess = 0.2
    initial_theta = 0.5 * np.arctan2(delta_guess * g_2d, xi_2d)
    initial_theta_flat = initial_theta.flatten()
    delta = 0
    sol = root(
        bcs_2d_system, 
        initial_theta_flat, 
        method='df-sane',
        tol=1e-6,
    )
    if sol.success:
        theta_res = sol.x.reshape(Nk, Nk)
        delta = g/2/N * np.sum(g_2d * np.sin(2 * theta_res))
        print(f" Delta: {delta:.6f}")
    else:
        print("error", sol.message)
    delta_results.append(delta)

x_plot = np.array(Doping_x_results)
Tc_plot = np.array(Tc_results)
delta_plot = np.array(delta_results)

mask_lower = x_plot >= 0.1
mask_upper = x_plot < 0.8
mask_combined = mask_lower & mask_upper

Tc_final = Tc_plot[mask_combined]
x_final = x_plot[mask_combined]
delta_final = delta_plot[mask_combined]

sort_indices = np.argsort(x_final)
x_final = x_final[sort_indices]
Tc_final = Tc_final[sort_indices]

end_time = time.time()
print(end_time-start_time)

plt.figure(figsize=(8, 8))
#plt.plot(x_final, Tc_final, 'ro-', linewidth=2, markersize=4, label=f'$U={U}, g={g}$, interacting')
#plt.plot(x_final_0, Tc_final_0, 'co-', linewidth=2, markersize=4, label=f'$U={U}, g={g}, non-interacting$')
plt.plot(x_final, Tc_final, 'o-', color='tab:orange', linewidth=2, markersize=4, label=f'$U={U}, g={g}$, interacting')
plt.title(f'Critical Temperature $T_c$ vs Doping $x = 1 - \\langle n \\rangle$')
plt.xlabel('Doping $x = 1 - \\langle n \\rangle$')
plt.ylabel('Critical Temperature $T_c / t$')
plt.grid(True, linestyle='--', alpha=0.7)
plt.xlim(0, 0.8)
plt.ylim(bottom=0)
plt.legend()
plt.show()
# Out:
# mu = 0.7 low Tc
# dopping_x = 6.423750420481156e-13 Tc = 0.0
# error too many function evaluations required
# mu = 0.6781879194630872 low Tc
# dopping_x = 6.520339823623544e-13 Tc = 0.0
#  Delta: 0.029033
# mu = 0.6563758389261745 low Tc
# dopping_x = 6.652456363553938e-13 Tc = 0.0
#  Delta: 0.024758
# mu = 0.6345637583892617 low Tc
# dopping_x = 6.52367049269742e-13 Tc = 0.0
#  Delta: 0.020619
# mu = 0.612751677852349 low Tc
# dopping_x = 6.394884621840902e-13 Tc = 0.0
#  Delta: 0.018338
# mu = 0.5909395973154362 low Tc
# dopping_x = 6.464828672392287e-13 Tc = 0.0
#  Delta: 0.016754
# mu = 0.5691275167785235 low Tc
# dopping_x = 6.582512313002553e-13 Tc = 0.0
#  Delta: 0.016375
# mu = 0.5473154362416107 low Tc
# dopping_x = 6.598055435347305e-13 Tc = 0.0
#  Delta: 0.015090
# mu = 0.525503355704698 low Tc
# dopping_x = 6.524780715722045e-13 Tc = 0.0
#  Delta: 0.014172
# mu = 0.5036912751677852 low Tc
# dopping_x = 6.556977183436175e-13 Tc = 0.0
#  Delta: 0.013747
# mu = 0.4818791946308725 low Tc
# dopping_x = 6.584732759051803e-13 Tc = 0.0
#  Delta: 0.013652
# mu = 0.46006711409395973 low Tc
# dopping_x = 6.5580874064608e-13 Tc = 0.0
#  Delta: 0.017052
# mu = 0.4382550335570469 low Tc
# dopping_x = 6.408207298136404e-13 Tc = 0.0
# error too many function evaluations required
# mu = 0.4164429530201342 low Tc
# dopping_x = 6.539213615042172e-13 Tc = 0.0
# error too many function evaluations required
# mu = 0.39463087248322143 low Tc
# dopping_x = 0.00013732910217745253 Tc = 0.0
# error too many function evaluations required
# mu = 0.3728187919463087 low Tc
# dopping_x = 0.0005035400396454781 Tc = 0.0
# error too many function evaluations required
# mu = 0.35100671140939593 low Tc
# dopping_x = 0.0010528564458538447 Tc = 0.0
# error too many function evaluations required
# mu = 0.3291946308724832 low Tc
# dopping_x = 0.0019683837895912992 Tc = 0.0
# error too many function evaluations required
# mu = 0.30738255033557044 low Tc
# dopping_x = 0.0030059814458180956 Tc = 0.0
# error too many function evaluations required
# mu = 0.2855704697986577 low Tc
# dopping_x = 0.004226684570811212 Tc = 0.0
# error too many function evaluations required
# mu = 0.26375838926174494 low Tc
# dopping_x = 0.005508422852030903 Tc = 0.0
# error too many function evaluations required
# mu = 0.2419463087248322 low Tc
# dopping_x = 0.00688171386764036 Tc = 0.0
# error too many function evaluations required
# dopping_x = 0.008347970276114003 Tc = 2.0837967922705183e-05
# error too many function evaluations required
# mu = 0.19832214765100664 low Tc
# dopping_x = 0.010055541992632366 Tc = 0.0
# error too many function evaluations required
# mu = 0.1765100671140939 low Tc
# dopping_x = 0.011642456055114714 Tc = 0.0
# error too many function evaluations required
# dopping_x = 0.013288503381806316 Tc = 3.6855804111493807e-06
# error too many function evaluations required
# mu = 0.1328859060402684 low Tc
# dopping_x = 0.015182495117580519 Tc = 0.0
#  Delta: 0.015980
# mu = 0.11107382550335565 low Tc
# dopping_x = 0.017227172851963735 Tc = 0.0
# error too many function evaluations required
# mu = 0.0892617449664429 low Tc
# dopping_x = 0.019332885742581962 Tc = 0.0
#  Delta: 0.017490
# dopping_x = 0.021500341100907927 Tc = 3.0702071031035334e-05
# error too many function evaluations required
# dopping_x = 0.02382067112572528 Tc = 0.0002279990448274576
# error too many function evaluations required
# mu = 0.023825503355704658 low Tc
# dopping_x = 0.025955200195669992 Tc = 0.0
# error too many function evaluations required
# dopping_x = 0.028473482314387177 Tc = 0.0007775621865818209
# error too many function evaluations required
# dopping_x = 0.030972606758826182 Tc = 0.0004600805030534714
# error too many function evaluations required
# dopping_x = 0.033384303895560685 Tc = 0.00171317278211075
# error too many function evaluations required
# dopping_x = 0.036017267591832214 Tc = 0.00249190555134273
# error too many function evaluations required
# dopping_x = 0.03876403445849319 Tc = 0.003938115851114682
# error too many function evaluations required
# dopping_x = 0.041583673998205284 Tc = 0.005721235484134529
# error too many function evaluations required
# dopping_x = 0.04447697054351352 Tc = 0.007984688528646873
# error too many function evaluations required
# dopping_x = 0.04745318698608403 Tc = 0.010699063950095043
# error too many function evaluations required
# dopping_x = 0.0505176356721172 Tc = 0.013863915372102301
# error too many function evaluations required
# dopping_x = 0.05367296418596612 Tc = 0.017482259780148373
#  Delta: 0.062535
# dopping_x = 0.05692205805347317 Tc = 0.021553788841137577
#  Delta: 0.070506
# dopping_x = 0.060268398811369805 Tc = 0.02607067730219263
# error too many function evaluations required
# dopping_x = 0.06371598917333121 Tc = 0.03101973639294525
# error too many function evaluations required
# dopping_x = 0.0672693592235254 Tc = 0.036385024439171285
#  Delta: 0.099940
# dopping_x = 0.07093361376549956 Tc = 0.04214911843898589
#  Delta: 0.111159
# dopping_x = 0.07471450568906601 Tc = 0.04829362116565342
#  Delta: 0.122902
# dopping_x = 0.07861854803631563 Tc = 0.05479937700023746
# error too many function evaluations required
# dopping_x = 0.08265319442715413 Tc = 0.06164656802187156
#  Delta: 0.147454
# dopping_x = 0.08682713087108274 Tc = 0.0688147610111304
#  Delta: 0.159989
# dopping_x = 0.09115069955759114 Tc = 0.07628288957871579
#  Delta: 0.172554
# dopping_x = 0.09563638292998489 Tc = 0.08402902813474458
#  Delta: 0.185094
# dopping_x = 0.10029914107360982 Tc = 0.09202975015567415
#  Delta: 0.197565
# dopping_x = 0.10515631024917593 Tc = 0.10025897588064021
#  Delta: 0.210489
# dopping_x = 0.11022681771696496 Tc = 0.10868647478742659
#  Delta: 0.221321
# dopping_x = 0.11552965224082423 Tc = 0.1172764409722328
#  Delta: 0.232820
# dopping_x = 0.12108178146171067 Tc = 0.12598665949209895
#  Delta: 0.243982
# dopping_x = 0.12689592673206052 Tc = 0.13476867985514365
#  Delta: 0.254789
# dopping_x = 0.13297870272402323 Tc = 0.14356915268458645
#  Delta: 0.264977
# dopping_x = 0.13932955626845667 Tc = 0.15233216441624706
#  Delta: 0.274852
# dopping_x = 0.14594071879685588 Tc = 0.16100213670890545
#  Delta: 0.284478
# dopping_x = 0.15279810818364847 Tc = 0.16952673379570096
#  Delta: 0.293392
# dopping_x = 0.1598828903060172 Tc = 0.17785927380715633
# error too many function evaluations required
# dopping_x = 0.16717331296880544 Tc = 0.18596032716584673
#  Delta: 0.313788
# dopping_x = 0.17464646023089525 Tc = 0.19379841791533947
#  Delta: 0.318460
# dopping_x = 0.18227969327425686 Tc = 0.20134993673247717
#  Delta: 0.324848
# dopping_x = 0.19005167948936452 Tc = 0.20859848205474762
#  Delta: 0.331722
# dopping_x = 0.19794301816358206 Tc = 0.2155338685958442
#  Delta: 0.338001
# dopping_x = 0.20593653243140575 Tc = 0.2221510082508267
#  Delta: 0.343990
# dopping_x = 0.21401731826638715 Tc = 0.22844880975693366
#  Delta: 0.349460
# dopping_x = 0.2221726364967862 Tc = 0.23442918454149866
#  Delta: 0.354595
# dopping_x = 0.2303917169121611 Tc = 0.2400961992296278
#  Delta: 0.359286
# dopping_x = 0.23866552394543894 Tc = 0.24545538340852197
#  Delta: 0.363575
# dopping_x = 0.24698651610487754 Tc = 0.2505131826221112
#  Delta: 0.367464
# dopping_x = 0.2553484180441776 Tc = 0.2552765376286539
#  Delta: 0.370955
# dopping_x = 0.26374601489910066 Tc = 0.25975256822347076

# %%
#Nk=32
U = 2.0
plt.plot(x_final, Tc_final, 'o-', color='tab:orange', linewidth=2, markersize=4, label=f'$U={U}, g={g}$, Tc')
plt.plot(x_final, delta_final, 'o-', linewidth=2, markersize=4, label=f'$U={U}, g={g}$, gap')
plt.xlabel('p')
plt.ylabel('Energy')
plt.grid(True, linestyle='--', alpha=0.7)
plt.xlim(0, 0.8)
plt.ylim(bottom=0)
plt.legend()
plt.show()

# %%
#Nk=64
U = 2.0
plt.plot(x_final, Tc_final, 'o-', color='tab:orange', linewidth=2, markersize=4, label=f'$U={U}, g={g}$, Tc')
plt.plot(x_final, delta_final, 'o-', linewidth=2, markersize=4, label=f'$U={U}, g={g}$, gap')
plt.xlabel('p')
plt.ylabel('Energy')
plt.grid(True, linestyle='--', alpha=0.7)
plt.xlim(0, 0.8)
plt.ylim(bottom=0)
plt.legend()
plt.show()

# %%
#Nk=128
U = 2.0
plt.plot(x_final, Tc_final, 'o-', color='tab:orange', linewidth=2, markersize=4, label=f'$U={U}, g={g}$, Tc')
plt.plot(x_final, delta_final, 'o-', linewidth=2, markersize=4, label=f'$U={U}, g={g}$, gap')
plt.xlabel('p')
plt.ylabel('Energy')
plt.grid(True, linestyle='--', alpha=0.7)
plt.xlim(0, 0.8)
plt.ylim(bottom=0)
plt.legend()
plt.show()

# %%
#Nk=256
U = 2.0
plt.plot(x_final, Tc_final, 'o-', color='tab:orange', linewidth=2, markersize=4, label=f'$U={U}, g={g}$, Tc')
plt.plot(x_final, delta_final, 'o-', linewidth=2, markersize=4, label=f'$U={U}, g={g}$, gap')
plt.xlabel('p')
plt.ylabel('Energy')
plt.grid(True, linestyle='--', alpha=0.7)
plt.xlim(0, 0.8)
plt.ylim(bottom=0)
plt.legend()
plt.show()

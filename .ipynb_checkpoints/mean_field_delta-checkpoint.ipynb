# %%
#Fermi arc model Tc equation 25 (non-interacting interacting splited)
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import fsolve
from scipy.optimize import brentq
from scipy.optimize import root
import time

kB = 1.0
t = 1.0
t1 = -0.2
t2 = 0.1
g = 2.0

Q = [np.pi, np.pi]

U = 2.0

Nk = 64
kx_list = np.linspace(-np.pi, np.pi, Nk, endpoint=False)
ky_list = np.linspace(-np.pi, np.pi, Nk, endpoint=False)
KX, KY = np.meshgrid(kx_list, ky_list)
N = Nk * Nk

k_points = np.linspace(-np.pi, np.pi, Nk, endpoint=False)
kx, ky = np.meshgrid(k_points, k_points)
Total_K_Points = Nk**2

def band(kx, ky):
    return -2.0*t*(np.cos(kx) + np.cos(ky)) - 4.0*t1*np.cos(kx)*np.cos(ky) - 2*t2*(np.cos(2*kx) + np.cos(2*ky))

def band_Q(kx, ky):
    return -2.0*t*(np.cos(kx+Q[0]) + np.cos(ky+Q[1])) - 4.0*t1*np.cos(kx+Q[0])*np.cos(ky+Q[1]) - 2*t2*(np.cos(2*(kx+Q[0])) + np.cos(2*(ky+Q[1])))

def occupation_Q_per_spin(epsilon, epsilon_Q, mu, U, T):
    epsilon_minus_mu = epsilon - mu
    epsilon_Q_minus_mu = epsilon_Q - mu
    if T < 1e-8:
        T = 1e-8
    beta = 1.0/T
    E_1 = -beta*epsilon_Q_minus_mu
    E_2 = -beta*(epsilon_minus_mu + epsilon_Q_minus_mu + U)
    E_3 = -beta*epsilon_minus_mu
    E_0 = np.full_like(E_1, 0)
    E_max = np.maximum.reduce([E_0, E_1, E_2, E_3])
    numerator = np.exp(E_1 - E_max) + np.exp(E_2 - E_max)
    denominator = np.exp(E_0 - E_max) + np.exp(E_3 - E_max) + np.exp(E_1 - E_max) + np.exp(E_2 - E_max)
    return numerator/denominator

def chi0_hk(T, mu, U):
    if T < 1e-8:
        T = 1e-8
    beta = 1.0/T
    epsilon = band(KX, KY)
    epsilon_Q = band_Q(KX, KY)
    n_k = occupation_Q_per_spin(epsilon, epsilon_Q, mu, U, T)
    epsilon_minus_mu = epsilon - mu
    epsilon_Q_minus_mu = epsilon_Q - mu
    gamma = np.cos(KX) - np.cos(KY)
    #gamma = 1
    
    term_1_denominator = 2.0*epsilon_minus_mu
    term_1_numerator = gamma*gamma*(1.0 - n_k)*np.tanh(beta*epsilon_minus_mu/2.0)
    term_1 = np.where(np.abs(epsilon_minus_mu) < 1e-6, 
                      (1.0 - n_k)*beta/4.0,
                     term_1_numerator/term_1_denominator)
    
    epsilon_plus_U = epsilon_minus_mu + U
    term_2_denominator = 2.0*epsilon_plus_U
    term_2_numerator = gamma*gamma*n_k*np.tanh(beta*epsilon_plus_U/2.0)
    term_2 = np.where(np.abs(epsilon_plus_U) < 1e-6, 
                      n_k*beta/4.0,
                     term_2_numerator/term_2_denominator)

    term_3_denominator = 2.0*epsilon_minus_mu + U
    term_3_numerator = gamma*gamma*n_k*(1-n_k)*U*(np.tanh(beta*epsilon_plus_U/2.0)/2/epsilon_plus_U - np.tanh(beta*epsilon_minus_mu/2.0)/2/epsilon_minus_mu)
    term_3 = term_3_numerator/term_3_denominator
    term_3 = 0
    
    chi0 = np.sum(term_1 + term_2 + term_3)/N
    return chi0

def tc_equation(T, mu, U, g):
    return g*chi0_hk(T, mu, U) - 1.0

def find_Tc(mu, U, g):
    T_max = 1.0
    T_min = 1e-7
    if tc_equation(T_max, mu, U, g) > 0:
        T_high = T_max
        while tc_equation(T_high, mu, U, g) > 0 and T_high < 10.0:
            T_high *= 2
        T_max = T_high
        print('T_high=', T_max)
    if tc_equation(T_min, mu, U, g) < 0:
        print('mu =', mu, 'low Tc')
        return 0.0
    try:
        Tc = brentq(tc_equation, T_min, T_max, args=(mu, U, g))
        return Tc
    except ValueError:
        return 0.0
    return Tc

def average_occupation(mu, T, U, KX, KY, N):
    epsilon = band(KX, KY)
    epsilon_Q = band_Q(KX, KY)
    n_k = occupation_Q_per_spin(epsilon, epsilon_Q, mu, U, T)
    return 2.0*np.sum(n_k) / N

def gamma_func(kx, ky):
    #gamma = 1.0
    gamma = np.cos(kx) - np.cos(ky)
    return gamma

def dispersion(kx, ky):
    ek = -2 * t * (np.cos(kx) + np.cos(ky))
    ek -= 4 * t1 * np.cos(kx) * np.cos(ky)
    ek -= 2 * t2 * (np.cos(2*kx) + np.cos(2*ky))
    ek -= mu
    return ek

kmap = np.empty(Nk, dtype=np.int32)

for i in range(Nk):
    kmap[i] = (i+Nk//2)%Nk

def bcs_2d_system(theta_flat):
    theta = theta_flat.reshape(Nk, Nk)
    
    sin_2t = np.sin(2 * theta)
    cos_2t = np.cos(2 * theta)

    sin_q = np.sin(theta[np.ix_(kmap, kmap)])
    
    gap_sum = 0.5*g/Total_K_Points * np.sum(g_2d * sin_2t)
    
    residual = 2 * xi_2d * sin_2t + 2*U*sin_2t*sin_q*sin_q- 2 * g_2d * cos_2t * gap_sum
    return residual.flatten()

mu_list = np.linspace(0.70, -2.55, 150)  #U=2.0
#mu_list = np.linspace(0.5, -2.75, 150)  #U=1.7
#mu_list = np.linspace(0.1, -3.15, 150)  #U=1.4
#mu_list = np.linspace(-0.15, -3.4, 150)  #U=1.1

Tc_results = []
Doping_x_results = []
delta_results = []

start_time = time.time()
for mu in mu_list:
    Tc = find_Tc(mu, U, g)
    T_threshold = 1e-6
    if Tc > T_threshold:
        avg_n = average_occupation(mu, Tc, U, KX, KY, N)
        doping_x = 1.0 - avg_n
    else:
        avg_n = average_occupation(mu, T_threshold, U, KX, KY, N)
        doping_x = 1.0 - avg_n
    print('dopping_x =', doping_x, 'Tc =', Tc)
    Tc_results.append(Tc)
    Doping_x_results.append(doping_x)
    
    xi_2d = dispersion(kx, ky)
    g_2d = gamma_func(kx, ky)
    delta_guess = 0.2
    initial_theta = 0.5 * np.arctan2(delta_guess * g_2d, xi_2d)
    initial_theta_flat = initial_theta.flatten()
    delta = 0
    sol = root(
        bcs_2d_system, 
        initial_theta_flat, 
        method='df-sane',
        tol=1e-6,
    )
    if sol.success:
        theta_res = sol.x.reshape(Nk, Nk)
        delta = g/2/Total_K_Points * np.sum(g_2d * np.sin(2 * theta_res))
        print(f" Delta: {delta:.6f}")
    else:
        print("error", sol.message)
    delta_results.append(delta)

x_plot = np.array(Doping_x_results)
Tc_plot = np.array(Tc_results)
delta_plot = np.array(delta_results)

mask_lower = x_plot >= 0.1
mask_upper = x_plot < 0.8
mask_combined = mask_lower & mask_upper

Tc_final = Tc_plot[mask_combined]
x_final = x_plot[mask_combined]
delta_final = delta_plot[mask_combined]

sort_indices = np.argsort(x_final)
x_final = x_final[sort_indices]
Tc_final = Tc_final[sort_indices]

end_time = time.time()
print(end_time-start_time)

plt.figure(figsize=(8, 8))
#plt.plot(x_final, Tc_final, 'ro-', linewidth=2, markersize=4, label=f'$U={U}, g={g}$, interacting')
#plt.plot(x_final_0, Tc_final_0, 'co-', linewidth=2, markersize=4, label=f'$U={U}, g={g}, non-interacting$')
plt.plot(x_final, Tc_final, 'o-', color='tab:orange', linewidth=2, markersize=4, label=f'$U={U}, g={g}$, interacting')
plt.title(f'Critical Temperature $T_c$ vs Doping $x = 1 - \\langle n \\rangle$')
plt.xlabel('Doping $x = 1 - \\langle n \\rangle$')
plt.ylabel('Critical Temperature $T_c / t$')
plt.grid(True, linestyle='--', alpha=0.7)
plt.xlim(0, 0.8)
plt.ylim(bottom=0)
plt.legend()
plt.show()
# Out:
# mu = 0.7 low Tc
# dopping_x = 5.7482907322992105e-12 Tc = 0.0
#  Delta: 0.132703
# mu = 0.6781879194630872 low Tc
# dopping_x = 5.7411853049416095e-12 Tc = 0.0
#  Delta: 0.129015
# mu = 0.6563758389261745 low Tc
# dopping_x = 6.0751403907488566e-12 Tc = 0.0
#  Delta: 0.125559
# mu = 0.6345637583892617 low Tc
# dopping_x = 5.9827698351000436e-12 Tc = 0.0
#  Delta: 0.122362
# mu = 0.612751677852349 low Tc
# dopping_x = 5.8264504332328215e-12 Tc = 0.0
#  Delta: 0.119437
# mu = 0.5909395973154362 low Tc
# dopping_x = 5.8548721426632255e-12 Tc = 0.0
#  Delta: 0.116786
# mu = 0.5691275167785235 low Tc
# dopping_x = 6.0325078266032506e-12 Tc = 0.0
#  Delta: 0.114406
# mu = 0.5473154362416107 low Tc
# dopping_x = 6.0893512454640586e-12 Tc = 0.0
#  Delta: 0.112282
# mu = 0.525503355704698 low Tc
# dopping_x = 5.895728349969431e-12 Tc = 0.0
#  Delta: 0.110399
# mu = 0.5036912751677852 low Tc
# dopping_x = 5.952571768830239e-12 Tc = 0.0
#  Delta: 0.108737
# mu = 0.4818791946308725 low Tc
# dopping_x = 5.838884931108623e-12 Tc = 0.0
#  Delta: 0.107280
# mu = 0.46006711409395973 low Tc
# dopping_x = 6.178169087434071e-12 Tc = 0.0
#  Delta: 0.106009
# mu = 0.4382550335570469 low Tc
# dopping_x = 5.774047906470514e-12 Tc = 0.0
#  Delta: 0.104909
# mu = 0.4164429530201342 low Tc
# dopping_x = 6.179501355063621e-12 Tc = 0.0
#  Delta: 0.103966
# mu = 0.39463087248322143 low Tc
# dopping_x = 0.0009765625055226934 Tc = 0.0
#  Delta: 0.103172
# mu = 0.3728187919463087 low Tc
# dopping_x = 0.0029296875052899907 Tc = 0.0
#  Delta: 0.102518
# mu = 0.35100671140939593 low Tc
# dopping_x = 0.0029296875050195403 Tc = 0.0
#  Delta: 0.102004
# mu = 0.3291946308724832 low Tc
# dopping_x = 0.004882812504927614 Tc = 0.0
#  Delta: 0.097897
# mu = 0.30738255033557044 low Tc
# dopping_x = 0.004882812504458656 Tc = 0.0
#  Delta: 0.101410
# mu = 0.2855704697986577 low Tc
# dopping_x = 0.0048828125049258375 Tc = 0.0
#  Delta: 0.101352
# dopping_x = 0.006255557300493431 Tc = 0.0009120154696260653
#  Delta: 0.101488
# mu = 0.2419463087248322 low Tc
# dopping_x = 0.006835937504408918 Tc = 0.0
# error too many function evaluations required
# mu = 0.22013422818791945 low Tc
# dopping_x = 0.006835937504098055 Tc = 0.0
#  Delta: 0.102619
# mu = 0.19832214765100664 low Tc
# dopping_x = 0.010742187504384049 Tc = 0.0
# error too many function evaluations required
# mu = 0.1765100671140939 low Tc
# dopping_x = 0.010742187504568346 Tc = 0.0
#  Delta: 0.104978
# mu = 0.15469798657718115 low Tc
# dopping_x = 0.016601562503790745 Tc = 0.0
#  Delta: 0.105977
# mu = 0.1328859060402684 low Tc
# dopping_x = 0.016601562503478107 Tc = 0.0
# error too many function evaluations required
# mu = 0.11107382550335565 low Tc
# dopping_x = 0.02050781250391509 Tc = 0.0
#  Delta: 0.108351
# mu = 0.0892617449664429 low Tc
# dopping_x = 0.020507812504082068 Tc = 0.0
#  Delta: 0.109665
# mu = 0.06744966442953015 low Tc
# dopping_x = 0.02050781250378364 Tc = 0.0
#  Delta: 0.111249
# dopping_x = 0.021218166512498304 Tc = 0.0038590028097509133
# error too many function evaluations required
# mu = 0.023825503355704658 low Tc
# dopping_x = 0.026367187503497647 Tc = 0.0
# error too many function evaluations required
# mu = 0.00201342281879191 low Tc
# dopping_x = 0.02832031250349587 Tc = 0.0
#  Delta: 0.102673
# mu = -0.019798657718120838 low Tc
# dopping_x = 0.03222656250338218 Tc = 0.0
#  Delta: 0.121278
# mu = -0.041610738255033586 low Tc
# dopping_x = 0.03222656250320455 Tc = 0.0
#  Delta: 0.124095
# dopping_x = 0.03706663417411549 Tc = 0.006396833458746304
#  Delta: 0.127051
# dopping_x = 0.04000298994061724 Tc = 0.009647392432908124
#  Delta: 0.130189
# dopping_x = 0.04288036408296714 Tc = 0.011692924792286405
#  Delta: 0.131238
# dopping_x = 0.045396645593194895 Tc = 0.009490324980502644
#  Delta: 0.137445
# dopping_x = 0.04610159553400617 Tc = 0.011270172140578237
#  Delta: 0.141757
# dopping_x = 0.04942549359960546 Tc = 0.020007961040909333
# error too many function evaluations required
# dopping_x = 0.05357098587626119 Tc = 0.025910519010694095
# error too many function evaluations required
# dopping_x = 0.05729850278491977 Tc = 0.03234137119347753
#  Delta: 0.147852
# dopping_x = 0.06073359218023899 Tc = 0.0400221713444761
#  Delta: 0.163136
# dopping_x = 0.0641933402106587 Tc = 0.04871049852886674
#  Delta: 0.168882
# dopping_x = 0.06782087015539484 Tc = 0.05839746139965079
#  Delta: 0.174971
# dopping_x = 0.07167045353471457 Tc = 0.06918825441312373
#  Delta: 0.181448
# dopping_x = 0.07575744850375388 Tc = 0.08103607382264376
#  Delta: 0.188366
# dopping_x = 0.08008916591136561 Tc = 0.09374628341325371
#  Delta: 0.195762
# dopping_x = 0.08468152743471369 Tc = 0.10703841822975825
# error too many function evaluations required
# dopping_x = 0.0895517160504975 Tc = 0.12057687783307895
#  Delta: 0.211616
# dopping_x = 0.09470577732491625 Tc = 0.13401490226035911
#  Delta: 0.219476
# dopping_x = 0.10013383284920374 Tc = 0.14705600344046735
#  Delta: 0.227290
# dopping_x = 0.10581341936966748 Tc = 0.15949607535017313
#  Delta: 0.235173
# dopping_x = 0.11171624220511278 Tc = 0.171227300887133
#  Delta: 0.243146
# dopping_x = 0.11781392744949248 Tc = 0.18221627680926966
#  Delta: 0.251211
# dopping_x = 0.12408118635190979 Tc = 0.1924764176929641
#  Delta: 0.259353
# dopping_x = 0.13049685306419534 Tc = 0.20204580448969
#  Delta: 0.267547
# dopping_x = 0.1370437545567984 Tc = 0.21097278012085868
#  Delta: 0.275709
# dopping_x = 0.1437081229242838 Tc = 0.21930773755753466
#  Delta: 0.283493
# dopping_x = 0.15047892385518613 Tc = 0.22709892569383539
#  Delta: 0.290892
# dopping_x = 0.15734725451360687 Tc = 0.23439058967271112
#  Delta: 0.298082
# dopping_x = 0.16430585356600047 Tc = 0.24122237065845134
#  Delta: 0.305073
# dopping_x = 0.17134872023335435 Tc = 0.2476293397993669
#  Delta: 0.316237
# dopping_x = 0.17847082443509066 Tc = 0.2536423223676226
#  Delta: 0.320552
# dopping_x = 0.18566788818541768 Tc = 0.2592883306909424
#  Delta: 0.328567
# dopping_x = 0.1929362209879597 Tc = 0.2645910145407759
#  Delta: 0.331006
# dopping_x = 0.20027259555357824 Tc = 0.2695710860899415
#  Delta: 0.336831
# dopping_x = 0.20767415346056617 Tc = 0.2742467019233123
#  Delta: 0.342270
# dopping_x = 0.21513833304477548 Tc = 0.2786337974621994
#  Delta: 0.347330
# dopping_x = 0.22266281384018138 Tc = 0.28274637532609503
#  Delta: 0.352063
# dopping_x = 0.23024547340146562 Tc = 0.2865967518274043
#  Delta: 0.356504
# dopping_x = 0.23788435344310777 Tc = 0.29019576665029756
#  Delta: 0.360668
# dopping_x = 0.24557763303467417 Tc = 0.2935529607600791
#  Delta: 0.364560
# dopping_x = 0.25332360717479296 Tc = 0.2966767271699631
#  Delta: 0.368180
# dopping_x = 0.2611206694922683 Tc = 0.29957443863833966
#  Delta: 0.371500
# dopping_x = 0.26896729813359377 Tc = 0.3022525557900067
#  Delta: 0.374418
# dopping_x = 0.2768620441243307 Tc = 0.30471671861144517
#  Delta: 0.376906
# dopping_x = 0.2848035216608331 Tc = 0.3069718237916897
#  Delta: 0.379062
# dopping_x = 0.2927903999123448 Tc = 0.30902208994900787
#  Delta: 0.380924
# dopping_x = 0.3008213960097993 Tc = 0.3108711124559959
#  Delta: 0.382514
# dopping_x = 0.30889526896304154 Tc = 0.31252190923404954
#  Delta: 0.383850
# dopping_x = 0.3170108143047402 Tc = 0.3139769586743553
#  Delta: 0.384943
# dopping_x = 0.32516685929544376 Tc = 0.31523823059750317
#  Delta: 0.385785
# dopping_x = 0.33336225855537227 Tc = 0.31630721100061393
#  Delta: 0.386354
# dopping_x = 0.34159589000923973 Tc = 0.3171849211731393
#  Delta: 0.386629
# dopping_x = 0.3498666510465175 Tc = 0.3178719316312345
#  Delta: 0.386625
# dopping_x = 0.3581734548102741 Tc = 0.3183683711983616
#  Delta: 0.386379
# dopping_x = 0.36651522653457347 Tc = 0.3186739314505169
#  Delta: 0.385920
# dopping_x = 0.374890899853743 Tc = 0.31878786664253983
#  Delta: 0.385263
# dopping_x = 0.38329941300694215 Tc = 0.31870898913402224
#  Delta: 0.384416
# dopping_x = 0.3917397048584579 Tc = 0.3184356602360531
#  Delta: 0.383379
# dopping_x = 0.4002107106479169 Tc = 0.31796577630002226
#  Delta: 0.382112
# dopping_x = 0.40871135737482756 Tc = 0.3172967497634769
#  Delta: 0.380520
# dopping_x = 0.41724055870802546 Tc = 0.31642548475173005
#  Delta: 0.378641
# dopping_x = 0.4257972092918888 Tc = 0.31534834670325584
#  Delta: 0.376543
# dopping_x = 0.43438017829652353 Tc = 0.3140611253368208
#  Delta: 0.374239
# dopping_x = 0.44298830202688466 Tc = 0.31255899010321814
#  Delta: 0.371738
# dopping_x = 0.45162037536421906 Tc = 0.3108364370534339
#  Delta: 0.369037
# dopping_x = 0.460275141758114 Tc = 0.3088872258160595
#  Delta: 0.366121
# dopping_x = 0.4689512814183714 Tc = 0.3067043050544214
#  Delta: 0.362948
# dopping_x = 0.4776473972615789 Tc = 0.30427972443321577
#  Delta: 0.359468
# dopping_x = 0.48636199804741664 Tc = 0.30160453065702997
#  Delta: 0.355675
# dopping_x = 0.49509347797889736 Tc = 0.2986686446036465
#  Delta: 0.351606
# dopping_x = 0.5038400918266902 Tc = 0.2954607159120734
#  Delta: 0.347295
# dopping_x = 0.5125999243527424 Tc = 0.2919679505662338
#  Delta: 0.342754
# dopping_x = 0.5213708524208241 Tc = 0.2881759060554327
#  Delta: 0.337987
# dopping_x = 0.5301504976574203 Tc = 0.28406824754329607
#  Delta: 0.332982
# dopping_x = 0.5389361668064634 Tc = 0.2796264571907379
#  Delta: 0.327661
# dopping_x = 0.5477247759302762 Tc = 0.27482948741858787
#  Delta: 0.321845
# dopping_x = 0.5565127532370833 Tc = 0.2696533476788112
#  Delta: 0.315636
# dopping_x = 0.565295913409532 Tc = 0.2640706137185787
#  Delta: 0.309117
# dopping_x = 0.5740692936636944 Tc = 0.2580498493904304
#  Delta: 0.302304
# dopping_x = 0.5828269381332739 Tc = 0.2515549358276958
#  Delta: 0.295209
# dopping_x = 0.5915616122588657 Tc = 0.24454431552574532
#  Delta: 0.287817
# dopping_x = 0.6002644225218158 Tc = 0.23697018773637626
#  Delta: 0.280059
# dopping_x = 0.608924309426899 Tc = 0.22877775298481767
#  Delta: 0.271759
# dopping_x = 0.6175273750464152 Tc = 0.219904729786531
#  Delta: 0.262809
# dopping_x = 0.62605600681962 Tc = 0.21028161444970922
#  Delta: 0.253329
# dopping_x = 0.634487783111893 Tc = 0.1998336268654116
#  Delta: 0.243443
# dopping_x = 0.642794232560236 Tc = 0.18848612869131506
#  Delta: 0.233213
# dopping_x = 0.6509397497570103 Tc = 0.17617662082810046
#  Delta: 0.222661
# dopping_x = 0.6588814704914827 Tc = 0.16287786828850337
#  Delta: 0.211740
# dopping_x = 0.6665717248125682 Tc = 0.14863623128600623
#  Delta: 0.200173
# dopping_x = 0.6739652538898039 Tc = 0.13362147787853004
#  Delta: 0.187075
# dopping_x = 0.68103170868772 Tc = 0.11816350805473742
#  Delta: 0.173239
# dopping_x = 0.6877680168187293 Tc = 0.10273073092400953
#  Delta: 0.159164
# dopping_x = 0.6941996286696206 Tc = 0.087830336620772
#  Delta: 0.145177
# dopping_x = 0.7003668205664396 Tc = 0.07388903033075812
#  Delta: 0.131429
# dopping_x = 0.7063166145527784 Tc = 0.06119590648665031
#  Delta: 0.117722
# dopping_x = 0.7121323246732923 Tc = 0.04989300936315958
#  Delta: 0.102800
# dopping_x = 0.7179124722902146 Tc = 0.039940030889860534
#  Delta: 0.084213
# dopping_x = 0.7234756498039698 Tc = 0.031270604496096616
#  Delta: 0.068217
# dopping_x = 0.7283436055941722 Tc = 0.024431044893897438
#  Delta: 0.057135
# dopping_x = 0.7329708036653259 Tc = 0.019643896818717598
#  Delta: 0.048955
# dopping_x = 0.7383276394420464 Tc = 0.015710892284111364
# error too many function evaluations required
# dopping_x = 0.7449520420410305 Tc = 0.010875580463354106
# error too many function evaluations required
# mu = -2.2882550335570473 low Tc
# dopping_x = 0.75537109375 Tc = 0.0
# error too many function evaluations required
# mu = -2.31006711409396 low Tc
# dopping_x = 0.75537109375 Tc = 0.0
# error too many function evaluations required
# dopping_x = 0.7593920473368317 Tc = 0.005404098295752964
# error too many function evaluations required
# mu = -2.353691275167785 low Tc
# dopping_x = 0.76318359375 Tc = 0.0
# error too many function evaluations required
# dopping_x = 0.7688856863550687 Tc = 0.0045341590538149614
# error too many function evaluations required
# mu = -2.3973154362416107 low Tc
# dopping_x = 0.77294921875 Tc = 0.0
# error too many function evaluations required
# mu = -2.4191275167785236 low Tc
# dopping_x = 0.78076171875 Tc = 0.0
# error too many function evaluations required
# mu = -2.4409395973154364 low Tc
# dopping_x = 0.78662109375 Tc = 0.0
# error too many function evaluations required
# mu = -2.4627516778523493 low Tc
# dopping_x = 0.78662109375 Tc = 0.0
# error too many function evaluations required
# mu = -2.484563758389262 low Tc
# dopping_x = 0.79443359375 Tc = 0.0
# error too many function evaluations required
# dopping_x = 0.7967278835835556 Tc = 0.001666527404738056
# error too many function evaluations required
# mu = -2.528187919463087 low Tc
# dopping_x = 0.80419921875 Tc = 0.0
# error too many function evaluations required
# dopping_x = 0.8088717361297851 Tc = 0.0007972876531207939
# error too many function evaluations required
# 35.4239706993103

# %%
 
def mean_field_gap_equation(Delta):
    #if Delta < 1e-8:
    #    Delta = 1e-8 
    epsilon = band(KX, KY)
    epsilon_Q = band_Q(KX, KY)
    g_k = np.cos(KX) - np.cos(KY)
    T = 0
    n_k = occupation_Q_per_spin(epsilon, epsilon_Q, mu, U, T)
    
    E_k = np.sqrt(epsilon*epsilon + Delta*Delta*g_k*g_k + 1e-6)
    E_k_U = np.sqrt((epsilon+U)*(epsilon+U) + Delta*Delta*g_k*g_k + 1e-6)
    
    f_k = (g_k*g_k*(1-n_k)) / (2 * E_k) + (g_k*g_k*n_k) / (2 * E_k_U)
    summation = np.sum(f_k) / Total_K_Points
    return g*summation - 1

for mu in mu_list:
    Tc = find_Tc(mu, U, g)
    T_threshold = 1e-6
    if Tc > T_threshold:
        avg_n = average_occupation(mu, Tc, U, KX, KY, N)
        doping_x = 1.0 - avg_n
    else:
        avg_n = average_occupation(mu, T_threshold, U, KX, KY, N)
        doping_x = 1.0 - avg_n
    print('dopping_x =', doping_x, 'Tc =', Tc)
    Tc_results.append(Tc)
    Doping_x_results.append(doping_x)
    
    delta_0 = fsolve(mean_field_gap_equation, Tc)[0]
# Out:
# mu = 0.7 low Tc
# dopping_x = 5.7482907322992105e-12 Tc = 0.0
# mu = 0.6781879194630872 low Tc
# dopping_x = 5.7411853049416095e-12 Tc = 0.0
# mu = 0.6563758389261745 low Tc
# dopping_x = 6.0751403907488566e-12 Tc = 0.0
# mu = 0.6345637583892617 low Tc
# dopping_x = 5.9827698351000436e-12 Tc = 0.0
# mu = 0.612751677852349 low Tc
# dopping_x = 5.8264504332328215e-12 Tc = 0.0
# mu = 0.5909395973154362 low Tc
# dopping_x = 5.8548721426632255e-12 Tc = 0.0
# mu = 0.5691275167785235 low Tc
# dopping_x = 6.0325078266032506e-12 Tc = 0.0
# mu = 0.5473154362416107 low Tc
# dopping_x = 6.0893512454640586e-12 Tc = 0.0
# mu = 0.525503355704698 low Tc
# dopping_x = 5.895728349969431e-12 Tc = 0.0
# mu = 0.5036912751677852 low Tc
# dopping_x = 5.952571768830239e-12 Tc = 0.0
# mu = 0.4818791946308725 low Tc
# dopping_x = 5.838884931108623e-12 Tc = 0.0
# mu = 0.46006711409395973 low Tc
# dopping_x = 6.178169087434071e-12 Tc = 0.0
# mu = 0.4382550335570469 low Tc
# dopping_x = 5.774047906470514e-12 Tc = 0.0
# mu = 0.4164429530201342 low Tc
# dopping_x = 6.179501355063621e-12 Tc = 0.0
# mu = 0.39463087248322143 low Tc
# dopping_x = 0.0009765625055226934 Tc = 0.0
# mu = 0.3728187919463087 low Tc
# dopping_x = 0.0029296875052899907 Tc = 0.0
# mu = 0.35100671140939593 low Tc
# dopping_x = 0.0029296875050195403 Tc = 0.0
# mu = 0.3291946308724832 low Tc
# dopping_x = 0.004882812504927614 Tc = 0.0
# mu = 0.30738255033557044 low Tc
# dopping_x = 0.004882812504458656 Tc = 0.0
# mu = 0.2855704697986577 low Tc
# dopping_x = 0.0048828125049258375 Tc = 0.0
# dopping_x = 0.006451923911849011 Tc = 0.0006746692249008826
# mu = 0.2419463087248322 low Tc
# dopping_x = 0.006835937504408918 Tc = 0.0
# mu = 0.22013422818791945 low Tc
# dopping_x = 0.006835937504098055 Tc = 0.0
# mu = 0.19832214765100664 low Tc
# dopping_x = 0.010742187504384049 Tc = 0.0
# mu = 0.1765100671140939 low Tc
# dopping_x = 0.010742187504568346 Tc = 0.0
# mu = 0.15469798657718115 low Tc
# dopping_x = 0.016601562503790745 Tc = 0.0
# mu = 0.1328859060402684 low Tc
# dopping_x = 0.016601562503478107 Tc = 0.0
# mu = 0.11107382550335565 low Tc
# dopping_x = 0.02050781250391509 Tc = 0.0
# mu = 0.0892617449664429 low Tc
# dopping_x = 0.020507812504082068 Tc = 0.0
# mu = 0.06744966442953015 low Tc
# dopping_x = 0.02050781250378364 Tc = 0.0
# dopping_x = 0.020914974318213098 Tc = 0.0017904320607999168
# mu = 0.023825503355704658 low Tc
# dopping_x = 0.026367187503497647 Tc = 0.0
# mu = 0.00201342281879191 low Tc
# dopping_x = 0.02832031250349587 Tc = 0.0
# mu = -0.019798657718120838 low Tc
# dopping_x = 0.03222656250338218 Tc = 0.0
# mu = -0.041610738255033586 low Tc
# dopping_x = 0.03222656250320455 Tc = 0.0
# dopping_x = 0.036812359099015146 Tc = 0.0038455977303244264
# dopping_x = 0.040043740234424696 Tc = 0.0016273336357211282
# dopping_x = 0.04318439796679929 Tc = 0.007741488857243143
# mu = -0.12885906040268458 low Tc
# dopping_x = 0.04589843750285638 Tc = 0.0
# mu = -0.15067114093959733 low Tc
# dopping_x = 0.04589843750298428 Tc = 0.0
# dopping_x = 0.04779191383476833 Tc = 0.011143569952930702
# dopping_x = 0.05319691666214199 Tc = 0.015423495102524543
# dopping_x = 0.05783743967692545 Tc = 0.017583242991634596
# dopping_x = 0.06113092098394135 Tc = 0.02236967591352598
# dopping_x = 0.06423973590898835 Tc = 0.028762858980561433
# dopping_x = 0.06753965330871758 Tc = 0.03488646545214712
# dopping_x = 0.07101823535686658 Tc = 0.04088803712412678
# dopping_x = 0.0746868418619483 Tc = 0.047179355167968666
# dopping_x = 0.07856136570543426 Tc = 0.05391825888498484
# dopping_x = 0.08261489229250218 Tc = 0.06103724049716448
# dopping_x = 0.08681353637469702 Tc = 0.06843823099924276
# dopping_x = 0.09115009198551949 Tc = 0.07607059754728553
# dopping_x = 0.09563868988460844 Tc = 0.0839181995021019
# dopping_x = 0.10030042999617839 Tc = 0.09197562472796444
# dopping_x = 0.10515637519059173 Tc = 0.10023410925657382
# dopping_x = 0.11022641157502533 Tc = 0.10867571899234711
# dopping_x = 0.11552927794828505 Tc = 0.11727207142843316
# dopping_x = 0.1210815718059669 Tc = 0.12598499714121653
# dopping_x = 0.12689584192793424 Tc = 0.13476808846633354
# dopping_x = 0.13297867852877943 Tc = 0.14356895580327755
# dopping_x = 0.13932955290196358 Tc = 0.15233210292085195
# dopping_x = 0.14594071983092316 Tc = 0.16100211861912778
# dopping_x = 0.15279810906731683 Tc = 0.1695267287606008
# dopping_x = 0.15988289056377547 Tc = 0.17785927247262534
# dopping_x = 0.16717331292984017 Tc = 0.18596032682491712
# dopping_x = 0.17464646013902096 Tc = 0.19379841782890528
# dopping_x = 0.18227969321317783 Tc = 0.2013499367090742
# dopping_x = 0.19005167946387336 Tc = 0.20859848204730164
# dopping_x = 0.1979430181583085 Tc = 0.21553386859295728
# dopping_x = 0.20593653243348353 Tc = 0.22215100824948275
# dopping_x = 0.21401731826934944 Tc = 0.228448809756124
# dopping_x = 0.22217263649862173 Tc = 0.2344291845410494
# dopping_x = 0.2303917169128522 Tc = 0.24009619922952727
# dopping_x = 0.2386655239454446 Tc = 0.2454553834083987
# dopping_x = 0.24698651610464695 Tc = 0.25051318262196454
# dopping_x = 0.2553484180439727 Tc = 0.2552765376286207
# dopping_x = 0.263746014898969 Tc = 0.2597525682233188
# dopping_x = 0.2721749725526942 Tc = 0.2639483406854448
# dopping_x = 0.2806316839405031 Tc = 0.26787070035624355
# dopping_x = 0.2891131395859392 Tc = 0.27152615385432044
# dopping_x = 0.2976168196794242 Tc = 0.2749207884052606
# dopping_x = 0.30614060475159244 Tc = 0.27806021840457346
# dopping_x = 0.314682702077435 Tc = 0.2809495515520095
# dopping_x = 0.3232415852026468 Tc = 0.28359336868783314
# dopping_x = 0.3318159443061659 Tc = 0.2859957128714073
# dopping_x = 0.34040464544453286 Tc = 0.2881600843289481
# dopping_x = 0.34900669703394915 Tc = 0.2900894387207042
# dopping_x = 0.35762122220110915 Tc = 0.2917861867919856
# dopping_x = 0.3662474358697937 Tc = 0.2932521939225133
# dopping_x = 0.37488462564766767 Tc = 0.2944887784107003
# dopping_x = 0.3835321357399516 Tc = 0.2954967075518277
# dopping_x = 0.39218935324773874 Tc = 0.2962761907129044
# dopping_x = 0.4008556963128016 Tc = 0.29682686868785135
# dopping_x = 0.4095306036515053 Tc = 0.297147798645416
# dopping_x = 0.41821352508096465 Tc = 0.29723743396595115
# dopping_x = 0.42690391268319505 Tc = 0.29709359820567705
# dopping_x = 0.43560121227925874 Tc = 0.2967134523292828
# dopping_x = 0.44430485489601845 Tc = 0.2960934542120191
# dopping_x = 0.453014247902896 Tc = 0.29522930922660207
# dopping_x = 0.46172876547377717 Tc = 0.2941159104913302
# dopping_x = 0.47044773798746764 Tc = 0.29274726705358456
# dopping_x = 0.4791704399144794 Tc = 0.29111641790764814
# dopping_x = 0.4878960756436449 Tc = 0.2892153292673107
# dopping_x = 0.4966237625672637 Tc = 0.2870347719386916
# dopping_x = 0.5053525105579862 Tc = 0.2845641749115453
# dopping_x = 0.5140811967156231 Tc = 0.28179145038767883
# dopping_x = 0.522808533906713 Tc = 0.27870278439028007
# dopping_x = 0.5315330311306246 Tc = 0.2752823857825632
# dopping_x = 0.5402529430632421 Tc = 0.2715121849983448
# dopping_x = 0.548966205171821 Tc = 0.26737147209829143
# dopping_x = 0.5576703494514775 Tc = 0.26283646204523303
# dopping_x = 0.566362393919424 Tc = 0.2578797738663004
# dopping_x = 0.5750386963121958 Tc = 0.25246981037935656
# dopping_x = 0.5836947586027437 Tc = 0.24657002862740973
# dopping_x = 0.5923249636301229 Tc = 0.2401381019219279
# dopping_x = 0.6009222178969953 Tc = 0.23312500087795568
# dopping_x = 0.6094774653851629 Tc = 0.22547407952028722
# dopping_x = 0.6179790272449399 Tc = 0.21712037618409635
# dopping_x = 0.626411716359898 Tc = 0.20799059007544052
# dopping_x = 0.6347556889102108 Tc = 0.19800468503026908
# dopping_x = 0.6429850654800885 Tc = 0.18708097387463662
# dopping_x = 0.6510665676737467 Tc = 0.17514800184435553
# dopping_x = 0.6589589213747559 Tc = 0.16216827200226908
# dopping_x = 0.6666146797653356 Tc = 0.14817872417559075
# dopping_x = 0.673986931752673 Tc = 0.13334483376371017
# dopping_x = 0.6810419766722293 Tc = 0.11800220784478072
# dopping_x = 0.6877728551724019 Tc = 0.10263545635458057
# dopping_x = 0.6942019936870609 Tc = 0.08777142202540843
# dopping_x = 0.7003679982627985 Tc = 0.07385137050792803
# dopping_x = 0.7063171961379877 Tc = 0.06117176963937183
# dopping_x = 0.7121326796237066 Tc = 0.049877786403454
# dopping_x = 0.7179127922615811 Tc = 0.03993070155814768
# dopping_x = 0.723475811805776 Tc = 0.03126513032702561
# dopping_x = 0.7283435069296976 Tc = 0.024427837844758164
# dopping_x = 0.7329706387944154 Tc = 0.019641880225988
# dopping_x = 0.738327551502157 Tc = 0.015709632410066753
# dopping_x = 0.7449520424134486 Tc = 0.010875004109001643
# mu = -2.2882550335570473 low Tc
# dopping_x = 0.75537109375 Tc = 0.0
# mu = -2.31006711409396 low Tc
# dopping_x = 0.75537109375 Tc = 0.0
# dopping_x = 0.7593920491596597 Tc = 0.005403968451175615
# mu = -2.353691275167785 low Tc
# dopping_x = 0.76318359375 Tc = 0.0
# dopping_x = 0.7688856993919349 Tc = 0.0045340710201568196
# mu = -2.3973154362416107 low Tc
# dopping_x = 0.77294921875 Tc = 0.0
# mu = -2.4191275167785236 low Tc
# dopping_x = 0.78076171875 Tc = 0.0
# mu = -2.4409395973154364 low Tc
# dopping_x = 0.78662109375 Tc = 0.0
# mu = -2.4627516778523493 low Tc
# dopping_x = 0.78662109375 Tc = 0.0
# mu = -2.484563758389262 low Tc
# dopping_x = 0.79443359375 Tc = 0.0
# dopping_x = 0.7967278853282023 Tc = 0.0016665171064756596
# mu = -2.528187919463087 low Tc
# dopping_x = 0.80419921875 Tc = 0.0
# dopping_x = 0.8088717349630501 Tc = 0.0007972855074786945

# %%
plt.figure(figsize=(8, 8))
#plt.plot(x_final, Tc_final, 'ro-', linewidth=2, markersize=4, label=f'$U={U}, g={g}$, interacting')
#plt.plot(x_final_0, Tc_final_0, 'co-', linewidth=2, markersize=4, label=f'$U={U}, g={g}, non-interacting$')
plt.plot(x_final, Tc_final, 'o-', color='tab:orange', linewidth=2, markersize=4, label=f'$U={U}, g={g}$, interacting')
plt.title(f'Critical Temperature $T_c$ vs Doping $x = 1 - \\langle n \\rangle$')
plt.xlabel('Doping $x = 1 - \\langle n \\rangle$')
plt.ylabel('Critical Temperature $T_c / t$')
plt.grid(True, linestyle='--', alpha=0.7)
plt.xlim(0, 0.8)
plt.ylim(bottom=0)
plt.legend()

# %%
plt.figure(figsize=(8, 8))
#plt.plot(x_final, Tc_final, 'ro-', linewidth=2, markersize=4, label=f'$U={U}, g={g}$, interacting')
#plt.plot(x_final_0, Tc_final_0, 'co-', linewidth=2, markersize=4, label=f'$U={U}, g={g}, non-interacting$')
plt.plot(x_final, Tc_final, 'o-', color='tab:orange', linewidth=2, markersize=4, label=f'$U={U}, g={g}$, interacting')
plt.title(f'Critical Temperature $T_c$ vs Doping $x = 1 - \\langle n \\rangle$')
plt.xlabel('Doping $x = 1 - \\langle n \\rangle$')
plt.ylabel('Critical Temperature $T_c / t$')
plt.grid(True, linestyle='--', alpha=0.7)
plt.xlim(0, 0.8)
plt.ylim(bottom=0)
plt.legend()

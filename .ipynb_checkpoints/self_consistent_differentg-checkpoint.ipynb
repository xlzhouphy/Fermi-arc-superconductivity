# %%
#Fermi arc model Tc equation 25 (non-interacting interacting splited)
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import fsolve
from scipy.optimize import brentq
from scipy.optimize import root
import time

kB = 1.0
t = 1.0
t1 = -0.2
t2 = 0.1
g = 0.8

Q = [np.pi, np.pi]

U = 2.0

Nk = 64*2*2
kx_list = np.linspace(0, np.pi, Nk, endpoint=False)
ky_list = np.linspace(0, np.pi, Nk, endpoint=False)
KX, KY = np.meshgrid(kx_list, ky_list)
N = Nk * Nk

Nk = 64*2
k_points = np.linspace(-np.pi, np.pi, Nk, endpoint=False)
kx, ky = np.meshgrid(k_points, k_points)
Total_K_Points = Nk**2

def band(kx, ky):
    return -2.0*t*(np.cos(kx) + np.cos(ky)) - 4.0*t1*np.cos(kx)*np.cos(ky) - 2*t2*(np.cos(2*kx) + np.cos(2*ky))

def band_Q(kx, ky):
    return -2.0*t*(np.cos(kx+Q[0]) + np.cos(ky+Q[1])) - 4.0*t1*np.cos(kx+Q[0])*np.cos(ky+Q[1]) - 2*t2*(np.cos(2*(kx+Q[0])) + np.cos(2*(ky+Q[1])))

def occupation_Q_per_spin(epsilon, epsilon_Q, mu, U, T):
    epsilon_minus_mu = epsilon - mu
    epsilon_Q_minus_mu = epsilon_Q - mu
    if T < 1e-8:
        T = 1e-8
    beta = 1.0/T
    E_1 = -beta*epsilon_Q_minus_mu
    E_2 = -beta*(epsilon_minus_mu + epsilon_Q_minus_mu + U)
    E_3 = -beta*epsilon_minus_mu
    E_0 = np.full_like(E_1, 0)
    E_max = np.maximum.reduce([E_0, E_1, E_2, E_3])
    numerator = np.exp(E_1 - E_max) + np.exp(E_2 - E_max)
    denominator = np.exp(E_0 - E_max) + np.exp(E_3 - E_max) + np.exp(E_1 - E_max) + np.exp(E_2 - E_max)
    return numerator/denominator

def chi0_hk(T, mu, U):
    if T < 1e-8:
        T = 1e-8
    beta = 1.0/T
    epsilon = band(KX, KY)
    epsilon_Q = band_Q(KX, KY)
    n_k = occupation_Q_per_spin(epsilon, epsilon_Q, mu, U, T)
    epsilon_minus_mu = epsilon - mu
    epsilon_Q_minus_mu = epsilon_Q - mu
    gamma = np.cos(KX) - np.cos(KY)
    #gamma = 1
    
    term_1_denominator = 2.0*epsilon_minus_mu
    term_1_numerator = gamma*gamma*(1.0 - n_k)*np.tanh(beta*epsilon_minus_mu/2.0)
    term_1 = np.where(np.abs(epsilon_minus_mu) < 1e-6, 
                      (1.0 - n_k)*beta/4.0,
                     term_1_numerator/term_1_denominator)
    
    epsilon_plus_U = epsilon_minus_mu + U
    term_2_denominator = 2.0*epsilon_plus_U
    term_2_numerator = gamma*gamma*n_k*np.tanh(beta*epsilon_plus_U/2.0)
    term_2 = np.where(np.abs(epsilon_plus_U) < 1e-6, 
                      n_k*beta/4.0,
                     term_2_numerator/term_2_denominator)

    term_3_denominator = 2.0*epsilon_minus_mu + U
    term_3_numerator = gamma*gamma*n_k*(1-n_k)*U*(np.tanh(beta*epsilon_plus_U/2.0)/2/epsilon_plus_U - np.tanh(beta*epsilon_minus_mu/2.0)/2/epsilon_minus_mu)
    term_3 = term_3_numerator/term_3_denominator
    #term_3 = 0
    
    chi0 = np.sum(term_1 + term_2 + term_3)/N
    return chi0

def tc_equation(T, mu, U, g):
    return g*chi0_hk(T, mu, U) - 1.0

def find_Tc(mu, U, g):
    T_max = 1.0
    T_min = 1e-7
    if tc_equation(T_max, mu, U, g) > 0:
        T_high = T_max
        while tc_equation(T_high, mu, U, g) > 0 and T_high < 10.0:
            T_high *= 2
        T_max = T_high
        print('T_high=', T_max)
    if tc_equation(T_min, mu, U, g) < 0:
        print('mu =', mu, 'low Tc')
        return 0.0
    try:
        Tc = brentq(tc_equation, T_min, T_max, args=(mu, U, g))
        return Tc
    except ValueError:
        return 0.0
    return Tc

def average_occupation(mu, T, U, KX, KY, N):
    epsilon = band(KX, KY)
    epsilon_Q = band_Q(KX, KY)
    n_k = occupation_Q_per_spin(epsilon, epsilon_Q, mu, U, T)
    return 2.0*np.sum(n_k) / N

def gamma_func(kx, ky):
    #gamma = 1.0
    gamma = np.cos(kx) - np.cos(ky)
    return gamma

def dispersion(kx, ky):
    ek = -2 * t * (np.cos(kx) + np.cos(ky))
    ek -= 4 * t1 * np.cos(kx) * np.cos(ky)
    ek -= 2 * t2 * (np.cos(2*kx) + np.cos(2*ky))
    ek -= mu
    return ek

kmap = np.empty(Nk, dtype=np.int32)

for i in range(Nk):
    kmap[i] = (i+Nk//2)%Nk

def bcs_2d_system(theta_flat):
    theta = theta_flat.reshape(Nk, Nk)
    
    sin_2t = np.sin(2 * theta)
    cos_2t = np.cos(2 * theta)

    sin_q = np.sin(theta[np.ix_(kmap, kmap)])
    
    gap_sum = 0.5*g/Total_K_Points * np.sum(g_2d * sin_2t)
    
    residual = 2 * xi_2d * sin_2t + 2*U*sin_2t*sin_q*sin_q- 2 * g_2d * cos_2t * gap_sum
    return residual.flatten()

mu_list = np.linspace(0.70, -2.55, 150)  #U=2.0
#mu_list = np.linspace(0.5, -2.75, 150)  #U=1.7
#mu_list = np.linspace(0.1, -3.15, 150)  #U=1.4
#mu_list = np.linspace(-0.15, -3.4, 150)  #U=1.1

Tc_results = []
Doping_x_results = []
delta_results = []

start_time = time.time()
for mu in mu_list:
    Tc = find_Tc(mu, U, g)
    T_threshold = 1e-6
    if Tc > T_threshold:
        avg_n = average_occupation(mu, Tc, U, KX, KY, N)
        doping_x = 1.0 - avg_n
    else:
        avg_n = average_occupation(mu, T_threshold, U, KX, KY, N)
        doping_x = 1.0 - avg_n
    print('dopping_x =', doping_x, 'Tc =', Tc)
    Tc_results.append(Tc)
    Doping_x_results.append(doping_x)
    
    xi_2d = dispersion(kx, ky)
    g_2d = gamma_func(kx, ky)
    delta_guess = 0.2
    initial_theta = 0.5 * np.arctan2(delta_guess * g_2d, xi_2d)
    initial_theta_flat = initial_theta.flatten()
    delta = 0
    sol = root(
        bcs_2d_system, 
        initial_theta_flat, 
        method='df-sane',
        tol=1e-6,
    )
    if sol.success:
        theta_res = sol.x.reshape(Nk, Nk)
        delta = g/2/Total_K_Points * np.sum(g_2d * np.sin(2 * theta_res))
        print(f" Delta: {delta:.6f}")
    else:
        print("error", sol.message)
    delta_results.append(delta)

x_plot = np.array(Doping_x_results)
Tc_plot = np.array(Tc_results)
delta_plot = np.array(delta_results)

mask_lower = x_plot >= 0.1
mask_upper = x_plot < 0.8
mask_combined = mask_lower & mask_upper

Tc_final = Tc_plot[mask_combined]
x_final = x_plot[mask_combined]
delta_final = delta_plot[mask_combined]

sort_indices = np.argsort(x_final)
x_final = x_final[sort_indices]
Tc_final = Tc_final[sort_indices]

end_time = time.time()
print(end_time-start_time)

plt.figure(figsize=(8, 8))
#plt.plot(x_final, Tc_final, 'ro-', linewidth=2, markersize=4, label=f'$U={U}, g={g}$, interacting')
#plt.plot(x_final_0, Tc_final_0, 'co-', linewidth=2, markersize=4, label=f'$U={U}, g={g}, non-interacting$')
plt.plot(x_final, Tc_final, 'o-', color='tab:orange', linewidth=2, markersize=4, label=f'$U={U}, g={g}$, interacting')
plt.title(f'Critical Temperature $T_c$ vs Doping $x = 1 - \\langle n \\rangle$')
plt.xlabel('Doping $x = 1 - \\langle n \\rangle$')
plt.ylabel('Critical Temperature $T_c / t$')
plt.grid(True, linestyle='--', alpha=0.7)
plt.xlim(0, 0.8)
plt.ylim(bottom=0)
plt.legend()
plt.show()
# Out:
# mu = 0.7 low Tc
# dopping_x = 0.007797241212201822 Tc = 0.0
#  Delta: 0.009691
# mu = 0.6781879194630872 low Tc
# dopping_x = 0.007797241212201822 Tc = 0.0
#  Delta: 0.009632
# mu = 0.6563758389261745 low Tc
# dopping_x = 0.007797241212235573 Tc = 0.0
#  Delta: 0.009599
# mu = 0.6345637583892617 low Tc
# dopping_x = 0.00779724121218317 Tc = 0.0
#  Delta: 0.009580
# mu = 0.612751677852349 low Tc
# dopping_x = 0.007797241212193384 Tc = 0.0
#  Delta: 0.009571
# mu = 0.5909395973154362 low Tc
# dopping_x = 0.007797241212206263 Tc = 0.0
#  Delta: 0.009567
# mu = 0.5691275167785235 low Tc
# dopping_x = 0.007797241212233796 Tc = 0.0
#  Delta: 0.009566
# mu = 0.5473154362416107 low Tc
# dopping_x = 0.007797241212207817 Tc = 0.0
#  Delta: 0.009566
# mu = 0.525503355704698 low Tc
# dopping_x = 0.007797241212211481 Tc = 0.0
# error too many function evaluations required
# mu = 0.5036912751677852 low Tc
# dopping_x = 0.007797241212208372 Tc = 0.0
#  Delta: 0.009565
# mu = 0.4818791946308725 low Tc
# dopping_x = 0.007797241212235462 Tc = 0.0
#  Delta: 0.009561
# mu = 0.46006711409395973 low Tc
# dopping_x = 0.0077972412121947166 Tc = 0.0
#  Delta: 0.009345
# mu = 0.4382550335570469 low Tc
# dopping_x = 0.0077972412121942725 Tc = 0.0
#  Delta: 0.009544
# mu = 0.4164429530201342 low Tc
# dopping_x = 0.007797241212218031 Tc = 0.0
#  Delta: 0.009529
# mu = 0.39463087248322143 low Tc
# dopping_x = 0.007934570313714584 Tc = 0.0
# error too many function evaluations required
# mu = 0.3728187919463087 low Tc
# dopping_x = 0.008300781251139311 Tc = 0.0
# error too many function evaluations required
# mu = 0.35100671140939593 low Tc
# dopping_x = 0.008850097657294498 Tc = 0.0
# error too many function evaluations required
# mu = 0.3291946308724832 low Tc
# dopping_x = 0.009765625001014633 Tc = 0.0
#  Delta: 0.009223
# mu = 0.30738255033557044 low Tc
# dopping_x = 0.010803222657231437 Tc = 0.0
# error too many function evaluations required
# mu = 0.2855704697986577 low Tc
# dopping_x = 0.012023925782201683 Tc = 0.0
# error too many function evaluations required
# mu = 0.26375838926174494 low Tc
# dopping_x = 0.013305664063382627 Tc = 0.0
# error too many function evaluations required
# mu = 0.2419463087248322 low Tc
# dopping_x = 0.014678955079009182 Tc = 0.0
# error too many function evaluations required
# dopping_x = 0.016155725449853553 Tc = 2.310535154717553e-06
# error too many function evaluations required
# mu = 0.19832214765100664 low Tc
# dopping_x = 0.017852783203984757 Tc = 0.0
# error too many function evaluations required
# mu = 0.1765100671140939 low Tc
# dopping_x = 0.019439697266410594 Tc = 0.0
# error too many function evaluations required
# mu = 0.15469798657718115 low Tc
# dopping_x = 0.021087646350705702 Tc = 0.0
# error too many function evaluations required
# mu = 0.1328859060402684 low Tc
# dopping_x = 0.022979736328886724 Tc = 0.0
# error too many function evaluations required
# mu = 0.11107382550335565 low Tc
# dopping_x = 0.025024414063241962 Tc = 0.0
# error too many function evaluations required
# mu = 0.0892617449664429 low Tc
# dopping_x = 0.02713012695381478 Tc = 0.0
# error too many function evaluations required
# mu = 0.06744966442953015 low Tc
# dopping_x = 0.029296875000685008 Tc = 0.0
# error too many function evaluations required
# mu = 0.045637583892617406 low Tc
# dopping_x = 0.0316162109382212 Tc = 0.0
#  Delta: 0.007663
# mu = 0.023825503355704658 low Tc
# dopping_x = 0.03375244140693834 Tc = 0.0
# error too many function evaluations required
# mu = 0.00201342281879191 low Tc
# dopping_x = 0.03631591796941358 Tc = 0.0
# error too many function evaluations required
# mu = -0.019798657718120838 low Tc
# dopping_x = 0.03878784179753947 Tc = 0.0
# error too many function evaluations required
# mu = -0.041610738255033586 low Tc
# dopping_x = 0.04119873046937883 Tc = 0.0
# error too many function evaluations required
# mu = -0.06342281879194633 low Tc
# dopping_x = 0.0437316894537374 Tc = 0.0
# error too many function evaluations required
# mu = -0.08523489932885908 low Tc
# dopping_x = 0.04650878906311273 Tc = 0.0
#  Delta: 0.007813
# mu = -0.10704697986577183 low Tc
# dopping_x = 0.04937744140682465 Tc = 0.0
# error too many function evaluations required
# mu = -0.12885906040268458 low Tc
# dopping_x = 0.05239868164118522 Tc = 0.0
# error too many function evaluations required
# mu = -0.15067114093959733 low Tc
# dopping_x = 0.055297851563081424 Tc = 0.0
# error too many function evaluations required
# mu = -0.17248322147651007 low Tc
# dopping_x = 0.05838012695368211 Tc = 0.0
#  Delta: 0.007809
# dopping_x = 0.06153797782666148 Tc = 7.477217343095677e-06
#  Delta: 0.008259
# dopping_x = 0.06486733569107495 Tc = 1.7194901828094534e-05
# error too many function evaluations required
# mu = -0.23791946308724832 low Tc
# dopping_x = 0.06781005859427269 Tc = 0.0
# error too many function evaluations required
# mu = -0.25973154362416107 low Tc
# dopping_x = 0.0712585449223686 Tc = 0.0
#  Delta: 0.008411
# mu = -0.2815436241610738 low Tc
# dopping_x = 0.07446289062614819 Tc = 0.0
#  Delta: 0.008224
# mu = -0.3033557046979867 low Tc
# dopping_x = 0.07839965820356964 Tc = 0.0
#  Delta: 0.008623
# mu = -0.3251677852348993 low Tc
# dopping_x = 0.08190917968794575 Tc = 0.0
#  Delta: 0.008374
# mu = -0.34697986577181217 low Tc
# dopping_x = 0.08563232421919964 Tc = 0.0
# error too many function evaluations required
# dopping_x = 0.08961951160530823 Tc = 6.376406323796145e-05
#  Delta: 0.008863
# mu = -0.39060402684563766 low Tc
# dopping_x = 0.09347534179728956 Tc = 0.0
# error too many function evaluations required
# dopping_x = 0.09765050857737023 Tc = 5.433122614609969e-05
#  Delta: 0.009029
# dopping_x = 0.10138510805905998 Tc = 3.80246147263424e-05
#  Delta: 0.009068
# mu = -0.4560402684563758 low Tc
# dopping_x = 0.10580444335975936 Tc = 0.0
#  Delta: 0.008971
# dopping_x = 0.11006492794385103 Tc = 9.568947721942287e-05
# error too many function evaluations required
# dopping_x = 0.11414560996513123 Tc = 6.63648304346509e-05
# error too many function evaluations required
# dopping_x = 0.11892856123049689 Tc = 0.00012271195085305163
#  Delta: 0.010104
# dopping_x = 0.12322027502513322 Tc = 0.00024011317047611827
# error too many function evaluations required
# dopping_x = 0.1282453168546831 Tc = 0.0001187709707123246
#  Delta: 0.010347
# dopping_x = 0.13305067941068138 Tc = 0.0005481440642204139
#  Delta: 0.011028
# dopping_x = 0.13796927652867352 Tc = 0.0005149147943765326
#  Delta: 0.011172
# dopping_x = 0.1430600454364066 Tc = 0.0007948000884229983
#  Delta: 0.011891
# dopping_x = 0.14829217131879768 Tc = 0.001204693438771002
#  Delta: 0.012163
# dopping_x = 0.1535385142149972 Tc = 0.001713534134609854
#  Delta: 0.013044
# dopping_x = 0.1589641707553504 Tc = 0.002273425141982343
#  Delta: 0.013407
# dopping_x = 0.16451880177288813 Tc = 0.0030406424937973143
#  Delta: 0.014467
# dopping_x = 0.17021503288468798 Tc = 0.004035495055689249
#  Delta: 0.015418
# dopping_x = 0.17607983064591903 Tc = 0.005264674811409343
#  Delta: 0.016415
# dopping_x = 0.18211119242222584 Tc = 0.006750444665195214
#  Delta: 0.018122
# dopping_x = 0.1883112034300054 Tc = 0.008523229666632303
#  Delta: 0.019482
# dopping_x = 0.19469176357930862 Tc = 0.010613209212500248
#  Delta: 0.021556
# dopping_x = 0.20126813116865305 Tc = 0.013046422094696695
#  Delta: 0.023661
# dopping_x = 0.20805844884304592 Tc = 0.015844230897301453
#  Delta: 0.026597
# dopping_x = 0.2150849433375277 Tc = 0.019021918439198177
#  Delta: 0.029567
# dopping_x = 0.22237594415911244 Tc = 0.02258706283971968
#  Delta: 0.032848
# dopping_x = 0.22996926426116904 Tc = 0.02653654853041116
#  Delta: 0.036523
# dopping_x = 0.23791824375766968 Tc = 0.030850575207122546
#  Delta: 0.040720
# dopping_x = 0.24629906008712055 Tc = 0.03548226762549651
#  Delta: 0.044917
# dopping_x = 0.25520972528709085 Tc = 0.04034608081731654
#  Delta: 0.049282
# dopping_x = 0.2647485880620005 Tc = 0.0453156880926133
#  Delta: 0.053771
# dopping_x = 0.2749770936346758 Tc = 0.050239722942123
#  Delta: 0.058384
# dopping_x = 0.28589189804871395 Tc = 0.05496842604362985
#  Delta: 0.062661
# dopping_x = 0.29742530955716506 Tc = 0.059375280544610026
#  Delta: 0.066649
# dopping_x = 0.30946852817907455 Tc = 0.06336542383664424
#  Delta: 0.070149
# dopping_x = 0.3218996681540329 Tc = 0.06687342050007622
#  Delta: 0.073233
# dopping_x = 0.3346039785649063 Tc = 0.06985624279024369
#  Delta: 0.075688
# dopping_x = 0.3474835333980584 Tc = 0.07228552949730334
#  Delta: 0.077432
# dopping_x = 0.36045911035037215 Tc = 0.07414090475048705
#  Delta: 0.078539
# dopping_x = 0.373467882234076 Tc = 0.07540477576941385
#  Delta: 0.079079
# dopping_x = 0.38645948958637044 Tc = 0.07605844333106182
#  Delta: 0.078885
# dopping_x = 0.39939180815416475 Tc = 0.07607920809117699
#  Delta: 0.077976
# dopping_x = 0.41222685532740444 Tc = 0.07543823355721505
#  Delta: 0.076478
# dopping_x = 0.4249267994680511 Tc = 0.07409916736048515
#  Delta: 0.074551
# dopping_x = 0.43744982315485037 Tc = 0.07201799345143613
#  Delta: 0.072092
# dopping_x = 0.449745610947328 Tc = 0.06914550946167672
#  Delta: 0.069037
# dopping_x = 0.46175068245409956 Tc = 0.0654355579906951
#  Delta: 0.065519
# dopping_x = 0.4733852892020105 Tc = 0.06086476310622586
#  Delta: 0.061707
# dopping_x = 0.4845570141586193 Tc = 0.05547069361506497
#  Delta: 0.057473
# dopping_x = 0.49518007925689755 Tc = 0.04940537290501162
#  Delta: 0.052631
# dopping_x = 0.5052129337023499 Tc = 0.04296669982911682
#  Delta: 0.047420
# dopping_x = 0.5146879394068461 Tc = 0.03654314573165567
#  Delta: 0.042227
# dopping_x = 0.5236936086924973 Tc = 0.03048109920231761
#  Delta: 0.037082
# dopping_x = 0.5323249014986174 Tc = 0.024995210056721964
#  Delta: 0.031469
# dopping_x = 0.5406547618563071 Tc = 0.02017806060719686
#  Delta: 0.026219
# dopping_x = 0.5487345621465918 Tc = 0.01604605095310103
# error too many function evaluations required
# dopping_x = 0.5566012069533126 Tc = 0.012572237353067605
#  Delta: 0.017725
# dopping_x = 0.5642816145793209 Tc = 0.009704893832641087
#  Delta: 0.014862
# dopping_x = 0.5717945820372792 Tc = 0.007378758575397816
#  Delta: 0.008360
# dopping_x = 0.5791508204425473 Tc = 0.005526287928872722
# error too many function evaluations required
# dopping_x = 0.5863831615548805 Tc = 0.004067364017752172
#  Delta: 0.008512
# dopping_x = 0.5934133200916385 Tc = 0.0029032644345379746
# error too many function evaluations required
# dopping_x = 0.6003205224098312 Tc = 0.0021332598780510904
# error too many function evaluations required
# dopping_x = 0.6074509141392059 Tc = 0.0016277510416327914
# error too many function evaluations required
# dopping_x = 0.6146902505110373 Tc = 0.0010382870462268712
# error too many function evaluations required
# dopping_x = 0.6211687530982811 Tc = 0.0004974862254929751
# error too many function evaluations required
# dopping_x = 0.6275080139272002 Tc = 0.0003531211558280511
# error too many function evaluations required
# dopping_x = 0.633772695668051 Tc = 0.00038926818427976133
# error too many function evaluations required
# dopping_x = 0.6400677930512821 Tc = 0.00020681771202729756
# error too many function evaluations required
# dopping_x = 0.6463683786274457 Tc = 0.00012400335576050973
# error too many function evaluations required
# mu = -1.8956375838926174 low Tc
# dopping_x = 0.6524658203125 Tc = 0.0
# error too many function evaluations required
# dopping_x = 0.6587416967077893 Tc = 6.675574228544345e-05
# error too many function evaluations required
# dopping_x = 0.6645794287860018 Tc = 4.8844453631503036e-05
# error too many function evaluations required
# mu = -1.9610738255033555 low Tc
# dopping_x = 0.6706542968765452 Tc = 0.0
# error too many function evaluations required
# dopping_x = 0.6769899804988111 Tc = 6.673056093618646e-05
# error too many function evaluations required
# mu = -2.004697986577181 low Tc
# dopping_x = 0.682769775390625 Tc = 0.0
# error too many function evaluations required
# mu = -2.026510067114094 low Tc
# dopping_x = 0.6883544921875 Tc = 0.0
# error too many function evaluations required
# mu = -2.0483221476510067 low Tc
# dopping_x = 0.6940917968749984 Tc = 0.0
# error too many function evaluations required
# mu = -2.0701342281879196 low Tc
# dopping_x = 0.699615478515625 Tc = 0.0
# error too many function evaluations required
# mu = -2.0919463087248324 low Tc
# dopping_x = 0.705169677734375 Tc = 0.0
# error too many function evaluations required
# mu = -2.1137583892617453 low Tc
# dopping_x = 0.7108154296875 Tc = 0.0
# error too many function evaluations required
# mu = -2.135570469798658 low Tc
# dopping_x = 0.71612548828125 Tc = 0.0
# error too many function evaluations required
# mu = -2.15738255033557 low Tc
# dopping_x = 0.721832275390625 Tc = 0.0
# error too many function evaluations required
# mu = -2.179194630872483 low Tc
# dopping_x = 0.72711181640625 Tc = 0.0
# error too many function evaluations required
# mu = -2.201006711409396 low Tc
# dopping_x = 0.73236083984375 Tc = 0.0
# error too many function evaluations required
# mu = -2.2228187919463087 low Tc
# dopping_x = 0.737457275390625 Tc = 0.0
# error too many function evaluations required
# mu = -2.2446308724832216 low Tc
# dopping_x = 0.742645263671875 Tc = 0.0
# error too many function evaluations required
# mu = -2.2664429530201344 low Tc
# dopping_x = 0.748046875 Tc = 0.0
# error too many function evaluations required
# mu = -2.2882550335570473 low Tc
# dopping_x = 0.753082275390625 Tc = 0.0
# error too many function evaluations required
# mu = -2.31006711409396 low Tc
# dopping_x = 0.757965087890625 Tc = 0.0
# error too many function evaluations required
# mu = -2.331879194630872 low Tc
# dopping_x = 0.7630615234375 Tc = 0.0
# error too many function evaluations required
# mu = -2.353691275167785 low Tc
# dopping_x = 0.76788330078125 Tc = 0.0
# error too many function evaluations required
# mu = -2.375503355704698 low Tc
# dopping_x = 0.772979736328125 Tc = 0.0
# error too many function evaluations required
# mu = -2.3973154362416107 low Tc
# dopping_x = 0.77801513671875 Tc = 0.0
#  Delta: 0.000000
# mu = -2.4191275167785236 low Tc
# dopping_x = 0.7827148437567437 Tc = 0.0
# error too many function evaluations required
# mu = -2.4409395973154364 low Tc
# dopping_x = 0.787384033203125 Tc = 0.0
# error too many function evaluations required
# mu = -2.4627516778523493 low Tc
# dopping_x = 0.792266845703125 Tc = 0.0
# error too many function evaluations required
# mu = -2.484563758389262 low Tc
# dopping_x = 0.79705810546875 Tc = 0.0
# error too many function evaluations required
# mu = -2.506375838926174 low Tc
# dopping_x = 0.801666259765625 Tc = 0.0
# error too many function evaluations required
# mu = -2.528187919463087 low Tc
# dopping_x = 0.806365966796875 Tc = 0.0
#  Delta: 0.000000
# mu = -2.55 low Tc
# dopping_x = 0.81103515625 Tc = 0.0
# error too many function evaluations required
# 315.4631145000458

# %%
U = 2.0
plt.plot(x_final, Tc_final, 'o-', color='tab:orange', linewidth=2, markersize=4, label=f'$U={U}, g={g}$, Tc')
plt.plot(x_final, delta_final, 'o-', linewidth=2, markersize=4, label=f'$U={U}, g={g}$, gap')
plt.xlabel('p')
plt.ylabel('Energy')
plt.grid(True, linestyle='--', alpha=0.7)
plt.xlim(0, 0.8)
plt.ylim(bottom=0)
plt.legend()
plt.savefig(f'temp')
plt.show()

# %%
U = 2.0
plt.plot(x_final, Tc_final, 'o-', color='tab:orange', linewidth=2, markersize=4, label=f'$U={U}, g={g}$, Tc')
plt.plot(x_final, delta_final, 'o-', linewidth=2, markersize=4, label=f'$U={U}, g={g}$, gap')
plt.xlabel('p')
plt.ylabel('Energy')
plt.grid(True, linestyle='--', alpha=0.7)
plt.xlim(0, 0.8)
plt.ylim(bottom=0)
plt.legend()
plt.savefig(f'temp')
plt.show()

# %%
ratio = 2*delta_final/Tc_final
plt.plot(x_final, ratio, '-')
# Out:
# C:\Users\fishb\AppData\Local\Temp\ipykernel_14932\2505689914.py:1: RuntimeWarning: divide by zero encountered in divide
#   ratio = 2*delta_final/Tc_final
# C:\Users\fishb\AppData\Local\Temp\ipykernel_14932\2505689914.py:1: RuntimeWarning: invalid value encountered in divide
#   ratio = 2*delta_final/Tc_final

# %%
#Fermi arc model Tc equation 25 (non-interacting interacting splited)
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import fsolve
from scipy.optimize import brentq
from scipy.optimize import root
import time

kB = 1.0
t = 1.0
t1 = -0.2
t2 = 0.1
g = 0.8

Q = [np.pi, np.pi]

U = 0.0

Nk = 64*2
kx_list = np.linspace(0, np.pi, Nk, endpoint=False)
ky_list = np.linspace(0, np.pi, Nk, endpoint=False)
KX, KY = np.meshgrid(kx_list, ky_list)
N = Nk * Nk

k_points = np.linspace(-np.pi, np.pi, Nk, endpoint=False)
kx, ky = np.meshgrid(k_points, k_points)
Total_K_Points = Nk**2

def band(kx, ky):
    return -2.0*t*(np.cos(kx) + np.cos(ky)) - 4.0*t1*np.cos(kx)*np.cos(ky) - 2*t2*(np.cos(2*kx) + np.cos(2*ky))

def band_Q(kx, ky):
    return -2.0*t*(np.cos(kx+Q[0]) + np.cos(ky+Q[1])) - 4.0*t1*np.cos(kx+Q[0])*np.cos(ky+Q[1]) - 2*t2*(np.cos(2*(kx+Q[0])) + np.cos(2*(ky+Q[1])))

def occupation_Q_per_spin(epsilon, epsilon_Q, mu, U, T):
    epsilon_minus_mu = epsilon - mu
    epsilon_Q_minus_mu = epsilon_Q - mu
    if T < 1e-8:
        T = 1e-8
    beta = 1.0/T
    E_1 = -beta*epsilon_Q_minus_mu
    E_2 = -beta*(epsilon_minus_mu + epsilon_Q_minus_mu + U)
    E_3 = -beta*epsilon_minus_mu
    E_0 = np.full_like(E_1, 0)
    E_max = np.maximum.reduce([E_0, E_1, E_2, E_3])
    numerator = np.exp(E_1 - E_max) + np.exp(E_2 - E_max)
    denominator = np.exp(E_0 - E_max) + np.exp(E_3 - E_max) + np.exp(E_1 - E_max) + np.exp(E_2 - E_max)
    return numerator/denominator

def chi0_hk(T, mu, U):
    if T < 1e-8:
        T = 1e-8
    beta = 1.0/T
    epsilon = band(KX, KY)
    epsilon_Q = band_Q(KX, KY)
    n_k = occupation_Q_per_spin(epsilon, epsilon_Q, mu, U, T)
    epsilon_minus_mu = epsilon - mu
    epsilon_Q_minus_mu = epsilon_Q - mu
    gamma = np.cos(KX) - np.cos(KY)
    #gamma = 1
    
    term_1_denominator = 2.0*epsilon_minus_mu
    term_1_numerator = gamma*gamma*(1.0 - n_k)*np.tanh(beta*epsilon_minus_mu/2.0)
    term_1 = np.where(np.abs(epsilon_minus_mu) < 1e-6, 
                      (1.0 - n_k)*beta/4.0,
                     term_1_numerator/term_1_denominator)
    
    epsilon_plus_U = epsilon_minus_mu + U
    term_2_denominator = 2.0*epsilon_plus_U
    term_2_numerator = gamma*gamma*n_k*np.tanh(beta*epsilon_plus_U/2.0)
    term_2 = np.where(np.abs(epsilon_plus_U) < 1e-6, 
                      n_k*beta/4.0,
                     term_2_numerator/term_2_denominator)

    term_3_denominator = 2.0*epsilon_minus_mu + U
    term_3_numerator = gamma*gamma*n_k*(1-n_k)*U*(np.tanh(beta*epsilon_plus_U/2.0)/2/epsilon_plus_U - np.tanh(beta*epsilon_minus_mu/2.0)/2/epsilon_minus_mu)
    term_3 = term_3_numerator/term_3_denominator
    #term_3 = 0
    
    chi0 = np.sum(term_1 + term_2 + term_3)/N
    return chi0

def tc_equation(T, mu, U, g):
    return g*chi0_hk(T, mu, U) - 1.0

def find_Tc(mu, U, g):
    T_max = 1.0
    T_min = 1e-7
    if tc_equation(T_max, mu, U, g) > 0:
        T_high = T_max
        while tc_equation(T_high, mu, U, g) > 0 and T_high < 10.0:
            T_high *= 2
        T_max = T_high
        print('T_high=', T_max)
    if tc_equation(T_min, mu, U, g) < 0:
        print('mu =', mu, 'low Tc')
        return 0.0
    try:
        Tc = brentq(tc_equation, T_min, T_max, args=(mu, U, g))
        return Tc
    except ValueError:
        return 0.0
    return Tc

def average_occupation(mu, T, U, KX, KY, N):
    epsilon = band(KX, KY)
    epsilon_Q = band_Q(KX, KY)
    n_k = occupation_Q_per_spin(epsilon, epsilon_Q, mu, U, T)
    return 2.0*np.sum(n_k) / N

def gamma_func(kx, ky):
    #gamma = 1.0
    gamma = np.cos(kx) - np.cos(ky)
    return gamma

def dispersion(kx, ky):
    ek = -2 * t * (np.cos(kx) + np.cos(ky))
    ek -= 4 * t1 * np.cos(kx) * np.cos(ky)
    ek -= 2 * t2 * (np.cos(2*kx) + np.cos(2*ky))
    ek -= mu
    return ek

kmap = np.empty(Nk, dtype=np.int32)

for i in range(Nk):
    kmap[i] = (i+Nk//2)%Nk

def bcs_2d_system(theta_flat):
    theta = theta_flat.reshape(Nk, Nk)
    
    sin_2t = np.sin(2 * theta)
    cos_2t = np.cos(2 * theta)

    sin_q = np.sin(theta[np.ix_(kmap, kmap)])
    
    gap_sum = 0.5*g/Total_K_Points * np.sum(g_2d * sin_2t)
    
    residual = 2 * xi_2d * sin_2t + 2*U*sin_2t*sin_q*sin_q- 2 * g_2d * cos_2t * gap_sum
    return residual.flatten()

mu_list = np.linspace(0.70, -2.55, 150)  #U=2.0
#mu_list = np.linspace(0.5, -2.75, 150)  #U=1.7
#mu_list = np.linspace(0.1, -3.15, 150)  #U=1.4
#mu_list = np.linspace(-0.15, -3.4, 150)  #U=1.1

Tc_results_0 = []
Doping_x_results_0 = []
delta_results_0 = []

start_time = time.time()
for mu in mu_list:
    Tc = find_Tc(mu, U, g)
    T_threshold = 1e-6
    if Tc > T_threshold:
        avg_n = average_occupation(mu, Tc, U, KX, KY, N)
        doping_x = 1.0 - avg_n
    else:
        avg_n = average_occupation(mu, T_threshold, U, KX, KY, N)
        doping_x = 1.0 - avg_n
    print('dopping_x =', doping_x, 'Tc =', Tc)
    Tc_results_0.append(Tc)
    Doping_x_results_0.append(doping_x)
    
    xi_2d = dispersion(kx, ky)
    g_2d = gamma_func(kx, ky)
    delta_guess = 0.2
    initial_theta = 0.5 * np.arctan2(delta_guess * g_2d, xi_2d)
    initial_theta_flat = initial_theta.flatten()
    delta_0 = 0
    sol = root(
        bcs_2d_system, 
        initial_theta_flat, 
        method='df-sane',
        tol=1e-6,
    )
    if sol.success:
        theta_res = sol.x.reshape(Nk, Nk)
        delta_0 = g/2/Total_K_Points * np.sum(g_2d * np.sin(2 * theta_res))
        print(f" Delta: {delta_0:.6f}")
    else:
        print("error", sol.message)
    delta_results_0.append(delta_0)

x_plot_0 = np.array(Doping_x_results_0)
Tc_plot_0 = np.array(Tc_results_0)
delta_plot_0 = np.array(delta_results_0)

mask_lower = x_plot_0 >= 0.1
mask_upper = x_plot_0 < 0.8
mask_combined = mask_lower & mask_upper

Tc_final_0 = Tc_plot_0[mask_combined]
x_final_0 = x_plot_0[mask_combined]
delta_final_0 = delta_plot_0[mask_combined]

sort_indices = np.argsort(x_final_0)
x_final_0 = x_final_0[sort_indices]
Tc_final_0 = Tc_final_0[sort_indices]

end_time = time.time()
print(end_time-start_time)

plt.figure(figsize=(8, 8))
#plt.plot(x_final, Tc_final, 'ro-', linewidth=2, markersize=4, label=f'$U={U}, g={g}$, interacting')
#plt.plot(x_final_0, Tc_final_0, 'co-', linewidth=2, markersize=4, label=f'$U={U}, g={g}, non-interacting$')
plt.plot(x_final_0, Tc_final_0, 'o-', color='tab:orange', linewidth=2, markersize=4, label=f'$U={U}, g={g}$, interacting')
plt.title(f'Critical Temperature $T_c$ vs Doping $x = 1 - \\langle n \\rangle$')
plt.xlabel('Doping $x = 1 - \\langle n \\rangle$')
plt.ylabel('Critical Temperature $T_c / t$')
plt.grid(True, linestyle='--', alpha=0.7)
plt.xlim(0, 0.8)
plt.ylim(bottom=0)
plt.legend()
plt.show()
# Out:
# mu = 0.7 low Tc
# dopping_x = -0.3072509765625 Tc = 0.0
#  Delta: 0.000003
# dopping_x = -0.3021599595095177 Tc = 0.000515983341949161
#  Delta: 0.001442
# dopping_x = -0.2974206882104202 Tc = 0.0009636831471510463
#  Delta: 0.000001
# dopping_x = -0.2915796818108558 Tc = 0.00039302881513549097
#  Delta: 0.000001
# mu = 0.612751677852349 low Tc
# dopping_x = -0.286865234375 Tc = 0.0
# error too many function evaluations required
# dopping_x = -0.28192713118454815 Tc = 0.0011389412903761134
# error too many function evaluations required
# mu = 0.5691275167785235 low Tc
# dopping_x = -0.2752685546875 Tc = 0.0
#  Delta: 0.002935
# dopping_x = -0.2711401819509234 Tc = 0.00019491118718068927
# error too many function evaluations required
# dopping_x = -0.2656306121815859 Tc = 0.0007138509309902825
#  Delta: 0.001184
# dopping_x = -0.2598639076039153 Tc = 0.0004852553152608677
#  Delta: 0.000001
# dopping_x = -0.254558333253031 Tc = 0.0005188223805030634
# error too many function evaluations required
# dopping_x = -0.24974146723247959 Tc = 0.00036091212312244715
# error too many function evaluations required
# dopping_x = -0.24326906448679808 Tc = 0.0012414490699228927
#  Delta: 0.003800
# dopping_x = -0.23802178144205266 Tc = 0.0005110156201256391
#  Delta: 0.001645
# dopping_x = -0.23300763096705968 Tc = 0.0005140127942756679
# error too many function evaluations required
# dopping_x = -0.22650134938428357 Tc = 0.0017591971941802106
#  Delta: 0.000006
# dopping_x = -0.22179570216586786 Tc = 0.0009174530872417201
#  Delta: 0.001673
# mu = 0.3291946308724832 low Tc
# dopping_x = -0.2161865234375 Tc = 0.0
#  Delta: 0.000004
# dopping_x = -0.21002647489838733 Tc = 0.0023675372583333793
#  Delta: 0.005443
# dopping_x = -0.2043430471219838 Tc = 0.0016873403572681093
#  Delta: 0.004891
# dopping_x = -0.19952311412867507 Tc = 0.0012039611576260708
#  Delta: 0.002306
# dopping_x = -0.1926072808014898 Tc = 0.003065351751123008
# error too many function evaluations required
# dopping_x = -0.18705856675202126 Tc = 0.0022883520797872246
#  Delta: 0.003184
# dopping_x = -0.182170334807924 Tc = 0.0026939265229860257
#  Delta: 0.004109
# dopping_x = -0.17533634942053644 Tc = 0.0038864588826147497
#  Delta: 0.007131
# dopping_x = -0.16963343376212436 Tc = 0.0030703306942745302
#  Delta: 0.006722
# dopping_x = -0.16413798895547016 Tc = 0.003990652888742533
#  Delta: 0.003710
# dopping_x = -0.15770626885608552 Tc = 0.004856775972307986
#  Delta: 0.004229
# dopping_x = -0.1515439741630502 Tc = 0.0040945918503489664
# error too many function evaluations required
# dopping_x = -0.1461292602909321 Tc = 0.005346228731829196
#  Delta: 0.008702
# dopping_x = -0.13932719852296538 Tc = 0.005974427592034663
#  Delta: 0.010422
# dopping_x = -0.13355580458689986 Tc = 0.005538613639740523
#  Delta: 0.008769
# dopping_x = -0.12752494948621806 Tc = 0.006931755708492118
#  Delta: 0.007244
# dopping_x = -0.12084448734258224 Tc = 0.0073382883842282405
#  Delta: 0.008251
# dopping_x = -0.11495759992829901 Tc = 0.0074157671008771905
#  Delta: 0.008906
# dopping_x = -0.10855853150595407 Tc = 0.008746620394428438
#  Delta: 0.013294
# dopping_x = -0.10204577249988822 Tc = 0.00909343517072979
#  Delta: 0.013927
# dopping_x = -0.09581271021410664 Tc = 0.0097036427633569
#  Delta: 0.012433
# dopping_x = -0.08929071234446773 Tc = 0.010838808585283667
#  Delta: 0.013036
# dopping_x = -0.08270181906066787 Tc = 0.011363237706180728
#  Delta: 0.013469
# dopping_x = -0.07628094890776316 Tc = 0.012340986259429181
#  Delta: 0.016492
# dopping_x = -0.0695522043887018 Tc = 0.013347158512196543
#  Delta: 0.018931
# dopping_x = -0.06291922617232704 Tc = 0.014196583566767229
#  Delta: 0.018771
# dopping_x = -0.05621059632563252 Tc = 0.015344443596283147
#  Delta: 0.018944
# dopping_x = -0.04938136759978451 Tc = 0.016417376634241285
#  Delta: 0.020061
# dopping_x = -0.04256839994784323 Tc = 0.017573016677581172
#  Delta: 0.022125
# dopping_x = -0.035642123023821526 Tc = 0.018839721250899947
#  Delta: 0.024827
# dopping_x = -0.0286706369842884 Tc = 0.020122206308615144
#  Delta: 0.025664
# dopping_x = -0.021634079828433794 Tc = 0.021509390715815545
#  Delta: 0.026511
# dopping_x = -0.014520946802220491 Tc = 0.022958771787493126
#  Delta: 0.028109
# dopping_x = -0.007343099143537479 Tc = 0.02448347456107048
#  Delta: 0.030243
# dopping_x = -8.821491578148155e-05 Tc = 0.026091589574456515
#  Delta: 0.032515
# dopping_x = 0.007242687694395622 Tc = 0.02777695046819216
#  Delta: 0.034079
# dopping_x = 0.01465323695285492 Tc = 0.029547634412939422
#  Delta: 0.035710
# dopping_x = 0.022147451680546992 Tc = 0.03140306844640944
#  Delta: 0.037888
# dopping_x = 0.029728367579990755 Tc = 0.03334599666116554
#  Delta: 0.040141
# dopping_x = 0.03740036964131421 Tc = 0.03537808888867086
#  Delta: 0.042387
# dopping_x = 0.045167726606978986 Tc = 0.03750066364221658
#  Delta: 0.044490
# dopping_x = 0.05303533867864563 Tc = 0.039714889046481024
#  Delta: 0.046785
# dopping_x = 0.06100859671427483 Tc = 0.04202134192760319
#  Delta: 0.049360
# dopping_x = 0.06909351528823193 Tc = 0.04442008243057556
#  Delta: 0.051835
# dopping_x = 0.07729686881632314 Tc = 0.04691041254382968
#  Delta: 0.054329
# dopping_x = 0.08562633930748997 Tc = 0.04949069242188206
#  Delta: 0.056906
# dopping_x = 0.09409071827855775 Tc = 0.052158057168357974
#  Delta: 0.059722
# dopping_x = 0.10270012615889668 Tc = 0.05490806130563303
#  Delta: 0.062454
# dopping_x = 0.11146623171780401 Tc = 0.05773423581193575
#  Delta: 0.065180
# dopping_x = 0.12040241211905911 Tc = 0.0606275723216712
#  Delta: 0.067968
# dopping_x = 0.1295237740053159 Tc = 0.06357597778801992
#  Delta: 0.070923
# dopping_x = 0.13884694186267255 Tc = 0.06656377955999734
#  Delta: 0.073828
# dopping_x = 0.1483895341939666 Tc = 0.06957139285762055
#  Delta: 0.076662
# dopping_x = 0.15816929778436684 Tc = 0.07257527272946812
#  Delta: 0.079500
# dopping_x = 0.16820295154888798 Tc = 0.07554824545261819
#  Delta: 0.082407
# dopping_x = 0.1785048814862884 Tc = 0.07846024608199362
#  Delta: 0.085288
# dopping_x = 0.18908589194858672 Tc = 0.08127939523021119
#  Delta: 0.088003
# dopping_x = 0.1999522249404838 Tc = 0.08397326175585233
#  Delta: 0.090637
# dopping_x = 0.2111050008647769 Tc = 0.08651011283421356
#  Delta: 0.093228
# dopping_x = 0.22254013311863485 Tc = 0.08885996541717071
#  Delta: 0.095743
# dopping_x = 0.234248664697428 Tc = 0.09099531360395359
#  Delta: 0.097990
# dopping_x = 0.24621740236710898 Tc = 0.09289148691574967
#  Delta: 0.100043
# dopping_x = 0.2584296976826326 Tc = 0.09452666547470902
#  Delta: 0.101924
# dopping_x = 0.2708662377308044 Tc = 0.09588162215101473
#  Delta: 0.103625
# dopping_x = 0.28350574431568953 Tc = 0.09693927642047524
#  Delta: 0.104948
# dopping_x = 0.29632552064351225 Tc = 0.09768413749534202
#  Delta: 0.105942
# dopping_x = 0.30930181780288 Tc = 0.09810169576155857
#  Delta: 0.106627
# dopping_x = 0.3224100148082929 Tc = 0.09817780043215482
#  Delta: 0.107005
# dopping_x = 0.33562461577731095 Tc = 0.0978980429570432
#  Delta: 0.106898
# dopping_x = 0.3489190681931442 Tc = 0.0972471526630309
#  Delta: 0.106324
# dopping_x = 0.3622653997255757 Tc = 0.09620840445533135
#  Delta: 0.105311
# dopping_x = 0.37563365981951924 Tc = 0.09476303942743916
#  Delta: 0.103885
# dopping_x = 0.38899113790135487 Tc = 0.09288971125604181
#  Delta: 0.101874
# dopping_x = 0.402301314932765 Tc = 0.09056400202906105
#  Delta: 0.099277
# dopping_x = 0.41552249482546544 Tc = 0.08775811780623273
#  Delta: 0.096148
# dopping_x = 0.42860607229941183 Tc = 0.084441011467909
#  Delta: 0.092550
# dopping_x = 0.44149446406478066 Tc = 0.08057945493880637
#  Delta: 0.088336
# dopping_x = 0.45411895687444626 Tc = 0.07614110775772004
#  Delta: 0.083466
# dopping_x = 0.46639831402218435 Tc = 0.07110153658198164
#  Delta: 0.078074
# dopping_x = 0.4782402615534125 Tc = 0.06545833444548882
#  Delta: 0.072351
# dopping_x = 0.489550039626803 Tc = 0.059255678982690574
#  Delta: 0.066191
# dopping_x = 0.5002511963105547 Tc = 0.05261735164982003
#  Delta: 0.059515
# dopping_x = 0.5103170550421655 Tc = 0.0457689654640629
#  Delta: 0.052639
# dopping_x = 0.5197918375269175 Tc = 0.039011758988126005
#  Delta: 0.046037
# dopping_x = 0.5287726319517865 Tc = 0.03263808051926162
#  Delta: 0.039729
# dopping_x = 0.5373627602593607 Tc = 0.026851198022201178
#  Delta: 0.033248
# dopping_x = 0.5456425843262864 Tc = 0.021749926559327438
#  Delta: 0.027358
# dopping_x = 0.5536639155896267 Tc = 0.017357097918261725
#  Delta: 0.021846
# dopping_x = 0.5614852741602254 Tc = 0.013649885571600805
#  Delta: 0.018256
# dopping_x = 0.569066579910938 Tc = 0.010580991017497089
#  Delta: 0.015190
# dopping_x = 0.5766002329697175 Tc = 0.008091139254473297
#  Delta: 0.008591
# dopping_x = 0.5836565165415333 Tc = 0.005965337717695546
# error too many function evaluations required
# dopping_x = 0.591491977494041 Tc = 0.004586348496290514
#  Delta: 0.008632
# dopping_x = 0.5973317283682467 Tc = 0.003348594868564502
# error too many function evaluations required
# dopping_x = 0.605119105720274 Tc = 0.0018618537104679094
# error too many function evaluations required
# dopping_x = 0.6121234120917913 Tc = 0.001856040210944839
#  Delta: 0.005487
# dopping_x = 0.6181227975847611 Tc = 0.0007859620602050333
# error too many function evaluations required
# mu = -1.7865771812080535 low Tc
# dopping_x = 0.626708984375 Tc = 0.0
# error too many function evaluations required
# dopping_x = 0.6309340669694607 Tc = 0.0004297703315008423
# error too many function evaluations required
# dopping_x = 0.6390506492869311 Tc = 0.0006657261375623599
# error too many function evaluations required
# dopping_x = 0.643523974192713 Tc = 0.0003223066677966166
# error too many function evaluations required
# dopping_x = 0.6512361962935261 Tc = 9.343135222323323e-05
# error too many function evaluations required
# mu = -1.8956375838926174 low Tc
# dopping_x = 0.6558837890625 Tc = 0.0
# error too many function evaluations required
# mu = -1.9174496644295302 low Tc
# dopping_x = 0.663330078125 Tc = 0.0
# error too many function evaluations required
# mu = -1.939261744966443 low Tc
# dopping_x = 0.66845703125 Tc = 0.0
# error too many function evaluations required
# mu = -1.9610738255033555 low Tc
# dopping_x = 0.674560546875 Tc = 0.0
# error too many function evaluations required
# dopping_x = 0.6814862936851777 Tc = 3.521017809501968e-05
# error too many function evaluations required
# mu = -2.004697986577181 low Tc
# dopping_x = 0.6856689453125 Tc = 0.0
# error too many function evaluations required
# mu = -2.026510067114094 low Tc
# dopping_x = 0.6929931640625 Tc = 0.0
# error too many function evaluations required
# mu = -2.0483221476510067 low Tc
# dopping_x = 0.6968994140625 Tc = 0.0
# error too many function evaluations required
# mu = -2.0701342281879196 low Tc
# dopping_x = 0.703857421875 Tc = 0.0
# error too many function evaluations required
# dopping_x = 0.7087407701001096 Tc = 1.7484682457275998e-05
# error too many function evaluations required
# mu = -2.1137583892617453 low Tc
# dopping_x = 0.71435546875 Tc = 0.0
#  Delta: 0.000000
# mu = -2.135570469798658 low Tc
# dopping_x = 0.7197265625 Tc = 0.0
# error too many function evaluations required
# mu = -2.15738255033557 low Tc
# dopping_x = 0.7254638671875 Tc = 0.0
# error too many function evaluations required
# mu = -2.179194630872483 low Tc
# dopping_x = 0.7310791015625 Tc = 0.0
#  Delta: 0.000001
# mu = -2.201006711409396 low Tc
# dopping_x = 0.7354736328125 Tc = 0.0
# error too many function evaluations required
# mu = -2.2228187919463087 low Tc
# dopping_x = 0.741455078125 Tc = 0.0
#  Delta: 0.000001
# mu = -2.2446308724832216 low Tc
# dopping_x = 0.74609375 Tc = 0.0
# error too many function evaluations required
# mu = -2.2664429530201344 low Tc
# dopping_x = 0.7509765625 Tc = 0.0
# error too many function evaluations required
# mu = -2.2882550335570473 low Tc
# dopping_x = 0.7569580078125 Tc = 0.0
# error too many function evaluations required
# mu = -2.31006711409396 low Tc
# dopping_x = 0.7611083984375 Tc = 0.0
# error too many function evaluations required
# mu = -2.331879194630872 low Tc
# dopping_x = 0.7664794921875 Tc = 0.0
# error too many function evaluations required
# mu = -2.353691275167785 low Tc
# dopping_x = 0.7708740234375 Tc = 0.0
# error too many function evaluations required
# mu = -2.375503355704698 low Tc
# dopping_x = 0.776123046875 Tc = 0.0
# error too many function evaluations required
# mu = -2.3973154362416107 low Tc
# dopping_x = 0.78125 Tc = 0.0
#  Delta: 0.000000
# mu = -2.4191275167785236 low Tc
# dopping_x = 0.7856445312769746 Tc = 0.0
#  Delta: 0.000000
# mu = -2.4409395973154364 low Tc
# dopping_x = 0.7904052734375 Tc = 0.0
#  Delta: -0.000000
# mu = -2.4627516778523493 low Tc
# dopping_x = 0.7952880859375 Tc = 0.0
# error too many function evaluations required
# mu = -2.484563758389262 low Tc
# dopping_x = 0.8001708984375 Tc = 0.0
# error too many function evaluations required
# mu = -2.506375838926174 low Tc
# dopping_x = 0.8046875 Tc = 0.0
# error too many function evaluations required
# mu = -2.528187919463087 low Tc
# dopping_x = 0.809326171875 Tc = 0.0
#  Delta: 0.000000
# mu = -2.55 low Tc
# dopping_x = 0.813720703125 Tc = 0.0
# error too many function evaluations required
# 189.78643679618835

# %%
U =0.0
plt.plot(x_final_0, Tc_final_0, 'o-', color='tab:orange', linewidth=2, markersize=4, label=f'$U={U}, g={g}$, Tc')
plt.plot(x_final_0, delta_final_0, 'o-', linewidth=2, markersize=4, label=f'$U={U}, g={g}$, gap')
plt.xlabel('p')
plt.ylabel('Energy')
plt.grid(True, linestyle='--', alpha=0.7)
plt.xlim(0, 0.8)
plt.ylim(bottom=0)
plt.legend()
plt.savefig(f'temp')
plt.show()

# %%
mask_ratio_0
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True])

# %%
mask_lower = x_final_0 >= 0.15
mask_upper = x_final_0 < 0.52
mask_ratio_0 = mask_lower & mask_upper

mask_lower = x_final >= 0.15
mask_upper = x_final < 0.52
mask_ratio = mask_lower & mask_upper

ratio_0 = 2*delta_final_0/Tc_final_0
ratio = 2*delta_final/Tc_final

ratio_0_plot = ratio_0[mask_ratio_0]
x_final_0_plot = x_final_0[mask_ratio_0]

ratio_plot = ratio[mask_ratio]
x_final_plot = x_final[mask_ratio]

plt.plot(x_final_0_plot, ratio_0_plot, '-', label='BCS')
plt.plot(x_final_plot, ratio_plot, '-', label='fermi arc')
plt.xlabel('p')
plt.ylabel('ratio')
plt.grid(True, linestyle='--', alpha=0.7)
plt.xlim(0, 0.8)
plt.ylim(bottom=0)
plt.legend()
plt.savefig(f'temp')
plt.show()
np.save(f'ratio_U=2_g=0.8', ratio)
np.save(f'Tc_U=2_g=0.8_ratio', Tc_final)
np.save(f'x_U=2_g=0.8_ratio', x_final)
np.save(f'ratio_0_U=2_g=0.8', ratio_0)
np.save(f'Tc_U=0_g=0.8_ratio', Tc_final_0)
np.save(f'x_U=0_g=0.8_ratio', x_final_0)
# Out:
# C:\Users\fishb\AppData\Local\Temp\ipykernel_14932\273065023.py:9: RuntimeWarning: divide by zero encountered in divide
#   ratio_0 = 2*delta_final_0/Tc_final_0
# C:\Users\fishb\AppData\Local\Temp\ipykernel_14932\273065023.py:9: RuntimeWarning: invalid value encountered in divide
#   ratio_0 = 2*delta_final_0/Tc_final_0
# C:\Users\fishb\AppData\Local\Temp\ipykernel_14932\273065023.py:10: RuntimeWarning: divide by zero encountered in divide
#   ratio = 2*delta_final/Tc_final
# C:\Users\fishb\AppData\Local\Temp\ipykernel_14932\273065023.py:10: RuntimeWarning: invalid value encountered in divide
#   ratio = 2*delta_final/Tc_final
